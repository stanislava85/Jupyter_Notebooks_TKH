# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 18 Lab</h1>
# </div>

# %% [markdown]
# For today's lab, we'll be using the Marvel comic book characters data set available from [538](https://github.com/fivethirtyeight/data/tree/master/comic-characters)
#
# The data comes from [Marvel Wikia](http://marvel.wikia.com/Main_Page) and [DC Wikia](http://dc.wikia.com/wiki/Main_Page). Characters were scraped on August 24. Appearance counts were scraped on September 2. The month and year of the first issue each character appeared in was pulled on October 6.
#
# The data is split into two files, for DC and Marvel, respectively: `dc-wikia-data.csv` and `marvel-wikia-data.csv`. Each file has the following variables:
#
# Variable | Definition
# ---|---------
# `page_id` | The unique identifier for that characters page within the wikia
# `name` | The name of the character
# `urlslug` | The unique url within the wikia that takes you to the character
# `ID` | The identity status of the character (Secret Identity, Public identity, [on marvel only: No Dual Identity])
# `ALIGN` | If the character is Good, Bad or Neutral
# `EYE` | Eye color of the character
# `HAIR` | Hair color of the character
# `SEX` | Sex of the character (e.g. Male, Female, etc.)
# `GSM` | If the character is a gender or sexual minority (e.g. Homosexual characters, bisexual characters)
# `ALIVE` | If the character is alive or deceased
# `APPEARANCES` | The number of appareances of the character in comic books (as of Sep. 2, 2014. Number will become increasingly out of date as time goes on.)
# `FIRST APPEARANCE` | The month and year of the character's first appearance in a comic book, if available
# `YEAR` | The year of the character's first appearance in a comic book, if available

# %% [markdown]
# Importing the libraries we'll be using

# %%
import numpy as np 
import pandas as pd 
import datetime

# %% [markdown]
# Let's open the `marvel-wikia-data.csv` file and generate a dataframe. Then we'll check the top of the `df` to see what we have.

# %%
df = pd.read_csv("../datasets/marvel-wikia-data.csv")
df
# Out:
#        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3        \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                        \/Thor_(Thor_Odinson)  No Dual Identity
# ...                                        ...               ...
# 16371                   \/Ru%27ach_(Earth-616)  No Dual Identity
# 16372      \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 16373          \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 16374         \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 16375                  \/Yologarch_(Earth-616)               NaN
#
#                     ALIGN         EYE        HAIR              SEX  GSM  \
# 0         Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1         Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2      Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3         Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4         Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
# ...                   ...         ...         ...              ...  ...
# 16371      Bad Characters  Green Eyes     No Hair  Male Characters  NaN
# 16372     Good Characters   Blue Eyes        Bald  Male Characters  NaN
# 16373      Bad Characters  Black Eyes        Bald  Male Characters  NaN
# 16374  Neutral Characters         NaN         NaN  Male Characters  NaN
# 16375      Bad Characters         NaN         NaN              NaN  NaN
#
#                    ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0      Living Characters       4043.0           Aug-62  1962.0
# 1      Living Characters       3360.0           Mar-41  1941.0
# 2      Living Characters       3061.0           Oct-74  1974.0
# 3      Living Characters       2961.0           Mar-63  1963.0
# 4      Living Characters       2258.0           Nov-50  1950.0
# ...                  ...          ...              ...     ...
# 16371  Living Characters          NaN              NaN     NaN
# 16372  Living Characters          NaN              NaN     NaN
# 16373  Living Characters          NaN              NaN     NaN
# 16374  Living Characters          NaN              NaN     NaN
# 16375  Living Characters          NaN              NaN     NaN
#
# [16376 rows x 13 columns]

# %% [markdown]
# As you can see we have a couple of issues:
# * The column `names` has, in some cases, both the hero name and their secret identity. In other cases, it has the universe the hero is from (usually Earth-616). We'd like for `name` to be the superhero. If a secret identity name is available, we'd like for that to be in it's own column. We'd also like a column `origin` for the superhero's place of origin (usually Earth-616).
# * The `urlslug` column is incorrect. We'd like for that to be a complete link. For example, spiderman's wikia link is https://marvel.fandom.com/wiki/Peter_Parker_(Earth-616) but if you use the `Spider-Man_(Peter_Parker)` from the `urlslug` (https://marvel.fandom.com/wiki/Spider-Man_(Peter_Parker), the page redirects to the correct page. You can choose to fix it various different ways but it should be a working link. Use "https://marvel.fandom.com/wiki/" as the beginning of your url.
# * For the column `align`, we'd like for the "Characters" part to be removed. We'd like for that column to be categorical (Good, Neutral, Evil or blank).
# * Same for the columns `EYE`, `HAIR`, `SEX` and `ID`. We want to drop the extraneous data and have simple categories (e.g. for `ID` we want categories ["Known","Public", "Secret", "None"] and for `SEX` we just want ["Male", "Female","Genderfluid","Agender"]. There's a way shown below that shows the various possible categories.
# * Some data is in the wrong format. For example, `Year` and `APPEARANCES` are floats but they really should be ints (as you cannot have a non-int number of appearances).
# * Some data doesn't match up (like the `FIRST APPEARANCE` and `Year` columns might have not be the same year)
# * Some columns are unnecessary. Some are missing data. Some rows are duplicates. Fix those as necessary.
# * Some column names are written as uppercase, some are lowercase and some are mixed case. Normalize them so all the column names are in the same format.
#
# Fix as many of these issues as you're able to. At the minimum, complete 4 of the above bulletpoints.

# %%
def see_possible_categories(col):
    return df.groupby(col).sum()
    
see_possible_categories('name')
# Out:
#                                                     page_id  APPEARANCES  \
# name
# 'Spinner (Earth-616)                                 322600          0.0
# 107 (Earth-616)                                      116257          1.0
# 11-Ball (Earth-616)                                  543479          1.0
# 115 (Legion Personality) (Earth-616)                 624448          1.0
# 14 (Earth-616)                                       116253          1.0
# ...                                                     ...          ...
# Zzxz (Earth-616)                                     250460          6.0
# Zzzax (Earth-616)                                      1553         32.0
# \"Spider-Girl\" (Mutant\/Spider Clone) (Earth-616)   689359          0.0
# \"Thumper\" Morgan (Earth-616)                       507442          0.0
# \u00c4kr\u00e4s (Earth-616)                          674537          0.0
#
#                                                       Year
# name
# 'Spinner (Earth-616)                                2007.0
# 107 (Earth-616)                                     1994.0
# 11-Ball (Earth-616)                                 1991.0
# 115 (Legion Personality) (Earth-616)                2010.0
# 14 (Earth-616)                                      1994.0
# ...                                                    ...
# Zzxz (Earth-616)                                    2009.0
# Zzzax (Earth-616)                                   1973.0
# \"Spider-Girl\" (Mutant\/Spider Clone) (Earth-616)  2013.0
# \"Thumper\" Morgan (Earth-616)                      1965.0
# \u00c4kr\u00e4s (Earth-616)                         2009.0
#
# [16376 rows x 3 columns]

# %%
df.shape
# Out:
# (16376, 13)

# %% [markdown]
# ## We'd like for name to be the superhero. If a secret identity name is available, we'd like for that to be in it's own column. We'd also like a column origin for the superhero's place of origin (usually Earth-616).

# %%
df["Secret_Identity"] = df['name'].str.split('(',3).str[1]

# %%
df["Secret_Identity"]=df["Secret_Identity"].str.split(")").str[0]
df
# Out:
#        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3        \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                        \/Thor_(Thor_Odinson)  No Dual Identity
# ...                                        ...               ...
# 16371                   \/Ru%27ach_(Earth-616)  No Dual Identity
# 16372      \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 16373          \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 16374         \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 16375                  \/Yologarch_(Earth-616)               NaN
#
#                     ALIGN         EYE        HAIR              SEX  GSM  \
# 0         Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1         Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2      Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3         Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4         Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
# ...                   ...         ...         ...              ...  ...
# 16371      Bad Characters  Green Eyes     No Hair  Male Characters  NaN
# 16372     Good Characters   Blue Eyes        Bald  Male Characters  NaN
# 16373      Bad Characters  Black Eyes        Bald  Male Characters  NaN
# 16374  Neutral Characters         NaN         NaN  Male Characters  NaN
# 16375      Bad Characters         NaN         NaN              NaN  NaN
#
#                    ALIVE  APPEARANCES FIRST APPEARANCE    Year  \
# 0      Living Characters       4043.0           Aug-62  1962.0
# 1      Living Characters       3360.0           Mar-41  1941.0
# 2      Living Characters       3061.0           Oct-74  1974.0
# 3      Living Characters       2961.0           Mar-63  1963.0
# 4      Living Characters       2258.0           Nov-50  1950.0
# ...                  ...          ...              ...     ...
# 16371  Living Characters          NaN              NaN     NaN
# 16372  Living Characters          NaN              NaN     NaN
# 16373  Living Characters          NaN              NaN     NaN
# 16374  Living Characters          NaN              NaN     NaN
# 16375  Living Characters          NaN              NaN     NaN
#
#                Secret_Identity
# 0                 Peter Parker
# 1                Steven Rogers
# 2      James \"Logan\" Howlett
# 3       Anthony \"Tony\" Stark
# 4                 Thor Odinson
# ...                        ...
# 16371                Earth-616
# 16372              Thanos' son
# 16373                   Skrull
# 16374               Spiderling
# 16375                Earth-616
#
# [16376 rows x 14 columns]

# %%
df["Origin"] = df['name'].str.split('(',3).str[2]
df
# Out:
#        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3        \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                        \/Thor_(Thor_Odinson)  No Dual Identity
# ...                                        ...               ...
# 16371                   \/Ru%27ach_(Earth-616)  No Dual Identity
# 16372      \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 16373          \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 16374         \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 16375                  \/Yologarch_(Earth-616)               NaN
#
#                     ALIGN         EYE        HAIR              SEX  GSM  \
# 0         Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1         Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2      Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3         Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4         Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
# ...                   ...         ...         ...              ...  ...
# 16371      Bad Characters  Green Eyes     No Hair  Male Characters  NaN
# 16372     Good Characters   Blue Eyes        Bald  Male Characters  NaN
# 16373      Bad Characters  Black Eyes        Bald  Male Characters  NaN
# 16374  Neutral Characters         NaN         NaN  Male Characters  NaN
# 16375      Bad Characters         NaN         NaN              NaN  NaN
#
#                    ALIVE  APPEARANCES FIRST APPEARANCE    Year  \
# 0      Living Characters       4043.0           Aug-62  1962.0
# 1      Living Characters       3360.0           Mar-41  1941.0
# 2      Living Characters       3061.0           Oct-74  1974.0
# 3      Living Characters       2961.0           Mar-63  1963.0
# 4      Living Characters       2258.0           Nov-50  1950.0
# ...                  ...          ...              ...     ...
# 16371  Living Characters          NaN              NaN     NaN
# 16372  Living Characters          NaN              NaN     NaN
# 16373  Living Characters          NaN              NaN     NaN
# 16374  Living Characters          NaN              NaN     NaN
# 16375  Living Characters          NaN              NaN     NaN
#
#                Secret_Identity      Origin
# 0                 Peter Parker         NaN
# 1                Steven Rogers         NaN
# 2      James \"Logan\" Howlett         NaN
# 3       Anthony \"Tony\" Stark         NaN
# 4                 Thor Odinson         NaN
# ...                        ...         ...
# 16371                Earth-616         NaN
# 16372              Thanos' son  Earth-616)
# 16373                   Skrull  Earth-616)
# 16374               Spiderling  Earth-616)
# 16375                Earth-616         NaN
#
# [16376 rows x 15 columns]

# %%
df["name"] = df['name'].str.split('(',3).str[0]
df
# Out:
#        page_id              name                                  urlslug  \
# 0         1678       Spider-Man               \/Spider-Man_(Peter_Parker)
# 1         7139  Captain America         \/Captain_America_(Steven_Rogers)
# 2        64786        Wolverine   \/Wolverine_(James_%22Logan%22_Howlett)
# 3         1868         Iron Man     \/Iron_Man_(Anthony_%22Tony%22_Stark)
# 4         2460             Thor                     \/Thor_(Thor_Odinson)
# ...        ...               ...                                      ...
# 16371   657508           Ru'ach                    \/Ru%27ach_(Earth-616)
# 16372   665474            Thane       \/Thane_(Thanos%27_son)_(Earth-616)
# 16373   695217         Tinkerer           \/Tinkerer_(Skrull)_(Earth-616)
# 16374   708811            TK421          \/TK421_(Spiderling)_(Earth-616)
# 16375   673702        Yologarch                   \/Yologarch_(Earth-616)
#
#                      ID               ALIGN         EYE        HAIR  \
# 0       Secret Identity     Good Characters  Hazel Eyes  Brown Hair
# 1       Public Identity     Good Characters   Blue Eyes  White Hair
# 2       Public Identity  Neutral Characters   Blue Eyes  Black Hair
# 3       Public Identity     Good Characters   Blue Eyes  Black Hair
# 4      No Dual Identity     Good Characters   Blue Eyes  Blond Hair
# ...                 ...                 ...         ...         ...
# 16371  No Dual Identity      Bad Characters  Green Eyes     No Hair
# 16372  No Dual Identity     Good Characters   Blue Eyes        Bald
# 16373   Secret Identity      Bad Characters  Black Eyes        Bald
# 16374   Secret Identity  Neutral Characters         NaN         NaN
# 16375               NaN      Bad Characters         NaN         NaN
#
#                    SEX  GSM              ALIVE  APPEARANCES FIRST APPEARANCE  \
# 0      Male Characters  NaN  Living Characters       4043.0           Aug-62
# 1      Male Characters  NaN  Living Characters       3360.0           Mar-41
# 2      Male Characters  NaN  Living Characters       3061.0           Oct-74
# 3      Male Characters  NaN  Living Characters       2961.0           Mar-63
# 4      Male Characters  NaN  Living Characters       2258.0           Nov-50
# ...                ...  ...                ...          ...              ...
# 16371  Male Characters  NaN  Living Characters          NaN              NaN
# 16372  Male Characters  NaN  Living Characters          NaN              NaN
# 16373  Male Characters  NaN  Living Characters          NaN              NaN
# 16374  Male Characters  NaN  Living Characters          NaN              NaN
# 16375              NaN  NaN  Living Characters          NaN              NaN
#
#          Year          Secret_Identity      Origin
# 0      1962.0             Peter Parker         NaN
# 1      1941.0            Steven Rogers         NaN
# 2      1974.0  James \"Logan\" Howlett         NaN
# 3      1963.0   Anthony \"Tony\" Stark         NaN
# 4      1950.0             Thor Odinson         NaN
# ...       ...                      ...         ...
# 16371     NaN                Earth-616         NaN
# 16372     NaN              Thanos' son  Earth-616)
# 16373     NaN                   Skrull  Earth-616)
# 16374     NaN               Spiderling  Earth-616)
# 16375     NaN                Earth-616         NaN
#
# [16376 rows x 15 columns]

# %% [markdown]
# ## The urlslug column is incorrect. We'd like for that to be a complete link. For example, spiderman's wikia link is https://marvel.fandom.com/wiki/Peter_Parker_(Earth-616) but if you use the Spider-Man_(Peter_Parker) from the urlslug (https://marvel.fandom.com/wiki/Spider-Man_(Peter_Parker), the page redirects to the correct page. You can choose to fix it various different ways but it should be a working link. Use "https://marvel.fandom.com/wiki/" as the beginning of your url.

# %%
#df["urlslug"]

# %%
df["urlslug"] = "https://marvel.fandom.com/wiki/" + df["urlslug"].str.split("/").str[1]

# %%
df["urlslug"]
# Out:
# 0        https://marvel.fandom.com/wiki/Spider-Man_(Pet...
# 1        https://marvel.fandom.com/wiki/Captain_America...
# 2        https://marvel.fandom.com/wiki/Wolverine_(Jame...
# 3        https://marvel.fandom.com/wiki/Iron_Man_(Antho...
# 4        https://marvel.fandom.com/wiki/Thor_(Thor_Odin...
#                                ...
# 16371    https://marvel.fandom.com/wiki/Ru%27ach_(Earth...
# 16372    https://marvel.fandom.com/wiki/Thane_(Thanos%2...
# 16373    https://marvel.fandom.com/wiki/Tinkerer_(Skrul...
# 16374    https://marvel.fandom.com/wiki/TK421_(Spiderli...
# 16375    https://marvel.fandom.com/wiki/Yologarch_(Eart...
# Name: urlslug, Length: 16376, dtype: object

# %%
df
# Out:
#        page_id              name  \
# 0         1678       Spider-Man
# 1         7139  Captain America
# 2        64786        Wolverine
# 3         1868         Iron Man
# 4         2460             Thor
# ...        ...               ...
# 16371   657508           Ru'ach
# 16372   665474            Thane
# 16373   695217         Tinkerer
# 16374   708811            TK421
# 16375   673702        Yologarch
#
#                                                  urlslug                ID  \
# 0      https://marvel.fandom.com/wiki/Spider-Man_(Pet...   Secret Identity
# 1      https://marvel.fandom.com/wiki/Captain_America...   Public Identity
# 2      https://marvel.fandom.com/wiki/Wolverine_(Jame...   Public Identity
# 3      https://marvel.fandom.com/wiki/Iron_Man_(Antho...   Public Identity
# 4      https://marvel.fandom.com/wiki/Thor_(Thor_Odin...  No Dual Identity
# ...                                                  ...               ...
# 16371  https://marvel.fandom.com/wiki/Ru%27ach_(Earth...  No Dual Identity
# 16372  https://marvel.fandom.com/wiki/Thane_(Thanos%2...  No Dual Identity
# 16373  https://marvel.fandom.com/wiki/Tinkerer_(Skrul...   Secret Identity
# 16374  https://marvel.fandom.com/wiki/TK421_(Spiderli...   Secret Identity
# 16375  https://marvel.fandom.com/wiki/Yologarch_(Eart...               NaN
#
#                     ALIGN         EYE        HAIR              SEX  GSM  \
# 0         Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1         Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2      Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3         Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4         Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
# ...                   ...         ...         ...              ...  ...
# 16371      Bad Characters  Green Eyes     No Hair  Male Characters  NaN
# 16372     Good Characters   Blue Eyes        Bald  Male Characters  NaN
# 16373      Bad Characters  Black Eyes        Bald  Male Characters  NaN
# 16374  Neutral Characters         NaN         NaN  Male Characters  NaN
# 16375      Bad Characters         NaN         NaN              NaN  NaN
#
#                    ALIVE  APPEARANCES FIRST APPEARANCE    Year  \
# 0      Living Characters       4043.0           Aug-62  1962.0
# 1      Living Characters       3360.0           Mar-41  1941.0
# 2      Living Characters       3061.0           Oct-74  1974.0
# 3      Living Characters       2961.0           Mar-63  1963.0
# 4      Living Characters       2258.0           Nov-50  1950.0
# ...                  ...          ...              ...     ...
# 16371  Living Characters          NaN              NaN     NaN
# 16372  Living Characters          NaN              NaN     NaN
# 16373  Living Characters          NaN              NaN     NaN
# 16374  Living Characters          NaN              NaN     NaN
# 16375  Living Characters          NaN              NaN     NaN
#
#                Secret_Identity      Origin
# 0                 Peter Parker         NaN
# 1                Steven Rogers         NaN
# 2      James \"Logan\" Howlett         NaN
# 3       Anthony \"Tony\" Stark         NaN
# 4                 Thor Odinson         NaN
# ...                        ...         ...
# 16371                Earth-616         NaN
# 16372              Thanos' son  Earth-616)
# 16373                   Skrull  Earth-616)
# 16374               Spiderling  Earth-616)
# 16375                Earth-616         NaN
#
# [16376 rows x 15 columns]

# %% [markdown]
# ## For the column align, we'd like for the "Characters" part to be removed. We'd like for that column to be categorical (Good, Neutral, Evil or blank).

# %%
df['ALIGN'] = df['ALIGN'].str.split('C').str[0]

# %%
df["ALIGN"] = df["ALIGN"].replace(["Bad "], "Evil")

# %%
df["ALIGN"].isna().sort_values(ascending=False) #which Align values are empty
# Out:
# 11838     True
# 2244      True
# 2227      True
# 13469     True
# 2228      True
#          ...
# 10316    False
# 10315    False
# 10314    False
# 10313    False
# 0        False
# Name: ALIGN, Length: 16376, dtype: bool

# %%
df["ALIGN"].isna().sum()  # how many Align values are empty
# Out:
# 2812

# %%
def see_possible_categories(col):
    return df.groupby(col).sum()
    
see_possible_categories("ALIGN")
# Out:
#              page_id  APPEARANCES        Year
# ALIGN
# Evil      2030768533      52910.0  12780912.0
# Good      1310680907     150603.0   8670851.0
# Neutral    771906748      41091.0   4122737.0

# %%
df
# Out:
#        page_id              name  \
# 0         1678       Spider-Man
# 1         7139  Captain America
# 2        64786        Wolverine
# 3         1868         Iron Man
# 4         2460             Thor
# ...        ...               ...
# 16371   657508           Ru'ach
# 16372   665474            Thane
# 16373   695217         Tinkerer
# 16374   708811            TK421
# 16375   673702        Yologarch
#
#                                                  urlslug                ID  \
# 0      https://marvel.fandom.com/wiki/Spider-Man_(Pet...   Secret Identity
# 1      https://marvel.fandom.com/wiki/Captain_America...   Public Identity
# 2      https://marvel.fandom.com/wiki/Wolverine_(Jame...   Public Identity
# 3      https://marvel.fandom.com/wiki/Iron_Man_(Antho...   Public Identity
# 4      https://marvel.fandom.com/wiki/Thor_(Thor_Odin...  No Dual Identity
# ...                                                  ...               ...
# 16371  https://marvel.fandom.com/wiki/Ru%27ach_(Earth...  No Dual Identity
# 16372  https://marvel.fandom.com/wiki/Thane_(Thanos%2...  No Dual Identity
# 16373  https://marvel.fandom.com/wiki/Tinkerer_(Skrul...   Secret Identity
# 16374  https://marvel.fandom.com/wiki/TK421_(Spiderli...   Secret Identity
# 16375  https://marvel.fandom.com/wiki/Yologarch_(Eart...               NaN
#
#           ALIGN         EYE        HAIR              SEX  GSM  \
# 0         Good   Hazel Eyes  Brown Hair  Male Characters  NaN
# 1         Good    Blue Eyes  White Hair  Male Characters  NaN
# 2      Neutral    Blue Eyes  Black Hair  Male Characters  NaN
# 3         Good    Blue Eyes  Black Hair  Male Characters  NaN
# 4         Good    Blue Eyes  Blond Hair  Male Characters  NaN
# ...         ...         ...         ...              ...  ...
# 16371      Evil  Green Eyes     No Hair  Male Characters  NaN
# 16372     Good    Blue Eyes        Bald  Male Characters  NaN
# 16373      Evil  Black Eyes        Bald  Male Characters  NaN
# 16374  Neutral          NaN         NaN  Male Characters  NaN
# 16375      Evil         NaN         NaN              NaN  NaN
#
#                    ALIVE  APPEARANCES FIRST APPEARANCE    Year  \
# 0      Living Characters       4043.0           Aug-62  1962.0
# 1      Living Characters       3360.0           Mar-41  1941.0
# 2      Living Characters       3061.0           Oct-74  1974.0
# 3      Living Characters       2961.0           Mar-63  1963.0
# 4      Living Characters       2258.0           Nov-50  1950.0
# ...                  ...          ...              ...     ...
# 16371  Living Characters          NaN              NaN     NaN
# 16372  Living Characters          NaN              NaN     NaN
# 16373  Living Characters          NaN              NaN     NaN
# 16374  Living Characters          NaN              NaN     NaN
# 16375  Living Characters          NaN              NaN     NaN
#
#                Secret_Identity      Origin
# 0                 Peter Parker         NaN
# 1                Steven Rogers         NaN
# 2      James \"Logan\" Howlett         NaN
# 3       Anthony \"Tony\" Stark         NaN
# 4                 Thor Odinson         NaN
# ...                        ...         ...
# 16371                Earth-616         NaN
# 16372              Thanos' son  Earth-616)
# 16373                   Skrull  Earth-616)
# 16374               Spiderling  Earth-616)
# 16375                Earth-616         NaN
#
# [16376 rows x 15 columns]

# %% [markdown]
# ## Same for the columns EYE, HAIR, SEX and ID. We want to drop the extraneous data and have simple categories (e.g. for ID we want categories ["Known","Public", "Secret", "None"] and for SEX we just want ["Male", "Female","Genderfluid","Agender"]. There's a way shown below that shows the various possible categories.

# %%
df['EYE'] = df['EYE'].str.split('E').str[0]
df
# Out:
#        page_id              name  \
# 0         1678       Spider-Man
# 1         7139  Captain America
# 2        64786        Wolverine
# 3         1868         Iron Man
# 4         2460             Thor
# ...        ...               ...
# 16371   657508           Ru'ach
# 16372   665474            Thane
# 16373   695217         Tinkerer
# 16374   708811            TK421
# 16375   673702        Yologarch
#
#                                                  urlslug                ID  \
# 0      https://marvel.fandom.com/wiki/Spider-Man_(Pet...   Secret Identity
# 1      https://marvel.fandom.com/wiki/Captain_America...   Public Identity
# 2      https://marvel.fandom.com/wiki/Wolverine_(Jame...   Public Identity
# 3      https://marvel.fandom.com/wiki/Iron_Man_(Antho...   Public Identity
# 4      https://marvel.fandom.com/wiki/Thor_(Thor_Odin...  No Dual Identity
# ...                                                  ...               ...
# 16371  https://marvel.fandom.com/wiki/Ru%27ach_(Earth...  No Dual Identity
# 16372  https://marvel.fandom.com/wiki/Thane_(Thanos%2...  No Dual Identity
# 16373  https://marvel.fandom.com/wiki/Tinkerer_(Skrul...   Secret Identity
# 16374  https://marvel.fandom.com/wiki/TK421_(Spiderli...   Secret Identity
# 16375  https://marvel.fandom.com/wiki/Yologarch_(Eart...               NaN
#
#           ALIGN     EYE        HAIR              SEX  GSM              ALIVE  \
# 0         Good   Hazel   Brown Hair  Male Characters  NaN  Living Characters
# 1         Good    Blue   White Hair  Male Characters  NaN  Living Characters
# 2      Neutral    Blue   Black Hair  Male Characters  NaN  Living Characters
# 3         Good    Blue   Black Hair  Male Characters  NaN  Living Characters
# 4         Good    Blue   Blond Hair  Male Characters  NaN  Living Characters
# ...         ...     ...         ...              ...  ...                ...
# 16371      Evil  Green      No Hair  Male Characters  NaN  Living Characters
# 16372     Good    Blue         Bald  Male Characters  NaN  Living Characters
# 16373      Evil  Black         Bald  Male Characters  NaN  Living Characters
# 16374  Neutral      NaN         NaN  Male Characters  NaN  Living Characters
# 16375      Evil     NaN         NaN              NaN  NaN  Living Characters
#
#        APPEARANCES FIRST APPEARANCE    Year          Secret_Identity  \
# 0           4043.0           Aug-62  1962.0             Peter Parker
# 1           3360.0           Mar-41  1941.0            Steven Rogers
# 2           3061.0           Oct-74  1974.0  James \"Logan\" Howlett
# 3           2961.0           Mar-63  1963.0   Anthony \"Tony\" Stark
# 4           2258.0           Nov-50  1950.0             Thor Odinson
# ...            ...              ...     ...                      ...
# 16371          NaN              NaN     NaN                Earth-616
# 16372          NaN              NaN     NaN              Thanos' son
# 16373          NaN              NaN     NaN                   Skrull
# 16374          NaN              NaN     NaN               Spiderling
# 16375          NaN              NaN     NaN                Earth-616
#
#            Origin
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 16371         NaN
# 16372  Earth-616)
# 16373  Earth-616)
# 16374  Earth-616)
# 16375         NaN
#
# [16376 rows x 15 columns]

# %%
df['HAIR'] = df['HAIR'].str.split('H').str[0]
df
# Out:
#        page_id              name  \
# 0         1678       Spider-Man
# 1         7139  Captain America
# 2        64786        Wolverine
# 3         1868         Iron Man
# 4         2460             Thor
# ...        ...               ...
# 16371   657508           Ru'ach
# 16372   665474            Thane
# 16373   695217         Tinkerer
# 16374   708811            TK421
# 16375   673702        Yologarch
#
#                                                  urlslug                ID  \
# 0      https://marvel.fandom.com/wiki/Spider-Man_(Pet...   Secret Identity
# 1      https://marvel.fandom.com/wiki/Captain_America...   Public Identity
# 2      https://marvel.fandom.com/wiki/Wolverine_(Jame...   Public Identity
# 3      https://marvel.fandom.com/wiki/Iron_Man_(Antho...   Public Identity
# 4      https://marvel.fandom.com/wiki/Thor_(Thor_Odin...  No Dual Identity
# ...                                                  ...               ...
# 16371  https://marvel.fandom.com/wiki/Ru%27ach_(Earth...  No Dual Identity
# 16372  https://marvel.fandom.com/wiki/Thane_(Thanos%2...  No Dual Identity
# 16373  https://marvel.fandom.com/wiki/Tinkerer_(Skrul...   Secret Identity
# 16374  https://marvel.fandom.com/wiki/TK421_(Spiderli...   Secret Identity
# 16375  https://marvel.fandom.com/wiki/Yologarch_(Eart...               NaN
#
#           ALIGN     EYE    HAIR              SEX  GSM              ALIVE  \
# 0         Good   Hazel   Brown   Male Characters  NaN  Living Characters
# 1         Good    Blue   White   Male Characters  NaN  Living Characters
# 2      Neutral    Blue   Black   Male Characters  NaN  Living Characters
# 3         Good    Blue   Black   Male Characters  NaN  Living Characters
# 4         Good    Blue   Blond   Male Characters  NaN  Living Characters
# ...         ...     ...     ...              ...  ...                ...
# 16371      Evil  Green      No   Male Characters  NaN  Living Characters
# 16372     Good    Blue     Bald  Male Characters  NaN  Living Characters
# 16373      Evil  Black     Bald  Male Characters  NaN  Living Characters
# 16374  Neutral      NaN     NaN  Male Characters  NaN  Living Characters
# 16375      Evil     NaN     NaN              NaN  NaN  Living Characters
#
#        APPEARANCES FIRST APPEARANCE    Year          Secret_Identity  \
# 0           4043.0           Aug-62  1962.0             Peter Parker
# 1           3360.0           Mar-41  1941.0            Steven Rogers
# 2           3061.0           Oct-74  1974.0  James \"Logan\" Howlett
# 3           2961.0           Mar-63  1963.0   Anthony \"Tony\" Stark
# 4           2258.0           Nov-50  1950.0             Thor Odinson
# ...            ...              ...     ...                      ...
# 16371          NaN              NaN     NaN                Earth-616
# 16372          NaN              NaN     NaN              Thanos' son
# 16373          NaN              NaN     NaN                   Skrull
# 16374          NaN              NaN     NaN               Spiderling
# 16375          NaN              NaN     NaN                Earth-616
#
#            Origin
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 16371         NaN
# 16372  Earth-616)
# 16373  Earth-616)
# 16374  Earth-616)
# 16375         NaN
#
# [16376 rows x 15 columns]

# %%
df['SEX'] = df['SEX'].str.split('C').str[0]

# %%
df
# Out:
#        page_id              name  \
# 0         1678       Spider-Man
# 1         7139  Captain America
# 2        64786        Wolverine
# 3         1868         Iron Man
# 4         2460             Thor
# ...        ...               ...
# 16371   657508           Ru'ach
# 16372   665474            Thane
# 16373   695217         Tinkerer
# 16374   708811            TK421
# 16375   673702        Yologarch
#
#                                                  urlslug                ID  \
# 0      https://marvel.fandom.com/wiki/Spider-Man_(Pet...   Secret Identity
# 1      https://marvel.fandom.com/wiki/Captain_America...   Public Identity
# 2      https://marvel.fandom.com/wiki/Wolverine_(Jame...   Public Identity
# 3      https://marvel.fandom.com/wiki/Iron_Man_(Antho...   Public Identity
# 4      https://marvel.fandom.com/wiki/Thor_(Thor_Odin...  No Dual Identity
# ...                                                  ...               ...
# 16371  https://marvel.fandom.com/wiki/Ru%27ach_(Earth...  No Dual Identity
# 16372  https://marvel.fandom.com/wiki/Thane_(Thanos%2...  No Dual Identity
# 16373  https://marvel.fandom.com/wiki/Tinkerer_(Skrul...   Secret Identity
# 16374  https://marvel.fandom.com/wiki/TK421_(Spiderli...   Secret Identity
# 16375  https://marvel.fandom.com/wiki/Yologarch_(Eart...               NaN
#
#           ALIGN     EYE    HAIR    SEX  GSM              ALIVE  APPEARANCES  \
# 0         Good   Hazel   Brown   Male   NaN  Living Characters       4043.0
# 1         Good    Blue   White   Male   NaN  Living Characters       3360.0
# 2      Neutral    Blue   Black   Male   NaN  Living Characters       3061.0
# 3         Good    Blue   Black   Male   NaN  Living Characters       2961.0
# 4         Good    Blue   Blond   Male   NaN  Living Characters       2258.0
# ...         ...     ...     ...    ...  ...                ...          ...
# 16371      Evil  Green      No   Male   NaN  Living Characters          NaN
# 16372     Good    Blue     Bald  Male   NaN  Living Characters          NaN
# 16373      Evil  Black     Bald  Male   NaN  Living Characters          NaN
# 16374  Neutral      NaN     NaN  Male   NaN  Living Characters          NaN
# 16375      Evil     NaN     NaN    NaN  NaN  Living Characters          NaN
#
#       FIRST APPEARANCE    Year          Secret_Identity      Origin
# 0               Aug-62  1962.0             Peter Parker         NaN
# 1               Mar-41  1941.0            Steven Rogers         NaN
# 2               Oct-74  1974.0  James \"Logan\" Howlett         NaN
# 3               Mar-63  1963.0   Anthony \"Tony\" Stark         NaN
# 4               Nov-50  1950.0             Thor Odinson         NaN
# ...                ...     ...                      ...         ...
# 16371              NaN     NaN                Earth-616         NaN
# 16372              NaN     NaN              Thanos' son  Earth-616)
# 16373              NaN     NaN                   Skrull  Earth-616)
# 16374              NaN     NaN               Spiderling  Earth-616)
# 16375              NaN     NaN                Earth-616         NaN
#
# [16376 rows x 15 columns]

# %%
df['ALIVE'] = df['ALIVE'].str.split('C').str[0]
df
# Out:
#        page_id              name  \
# 0         1678       Spider-Man
# 1         7139  Captain America
# 2        64786        Wolverine
# 3         1868         Iron Man
# 4         2460             Thor
# ...        ...               ...
# 16371   657508           Ru'ach
# 16372   665474            Thane
# 16373   695217         Tinkerer
# 16374   708811            TK421
# 16375   673702        Yologarch
#
#                                                  urlslug                ID  \
# 0      https://marvel.fandom.com/wiki/Spider-Man_(Pet...   Secret Identity
# 1      https://marvel.fandom.com/wiki/Captain_America...   Public Identity
# 2      https://marvel.fandom.com/wiki/Wolverine_(Jame...   Public Identity
# 3      https://marvel.fandom.com/wiki/Iron_Man_(Antho...   Public Identity
# 4      https://marvel.fandom.com/wiki/Thor_(Thor_Odin...  No Dual Identity
# ...                                                  ...               ...
# 16371  https://marvel.fandom.com/wiki/Ru%27ach_(Earth...  No Dual Identity
# 16372  https://marvel.fandom.com/wiki/Thane_(Thanos%2...  No Dual Identity
# 16373  https://marvel.fandom.com/wiki/Tinkerer_(Skrul...   Secret Identity
# 16374  https://marvel.fandom.com/wiki/TK421_(Spiderli...   Secret Identity
# 16375  https://marvel.fandom.com/wiki/Yologarch_(Eart...               NaN
#
#           ALIGN     EYE    HAIR    SEX  GSM    ALIVE  APPEARANCES  \
# 0         Good   Hazel   Brown   Male   NaN  Living        4043.0
# 1         Good    Blue   White   Male   NaN  Living        3360.0
# 2      Neutral    Blue   Black   Male   NaN  Living        3061.0
# 3         Good    Blue   Black   Male   NaN  Living        2961.0
# 4         Good    Blue   Blond   Male   NaN  Living        2258.0
# ...         ...     ...     ...    ...  ...      ...          ...
# 16371      Evil  Green      No   Male   NaN  Living           NaN
# 16372     Good    Blue     Bald  Male   NaN  Living           NaN
# 16373      Evil  Black     Bald  Male   NaN  Living           NaN
# 16374  Neutral      NaN     NaN  Male   NaN  Living           NaN
# 16375      Evil     NaN     NaN    NaN  NaN  Living           NaN
#
#       FIRST APPEARANCE    Year          Secret_Identity      Origin
# 0               Aug-62  1962.0             Peter Parker         NaN
# 1               Mar-41  1941.0            Steven Rogers         NaN
# 2               Oct-74  1974.0  James \"Logan\" Howlett         NaN
# 3               Mar-63  1963.0   Anthony \"Tony\" Stark         NaN
# 4               Nov-50  1950.0             Thor Odinson         NaN
# ...                ...     ...                      ...         ...
# 16371              NaN     NaN                Earth-616         NaN
# 16372              NaN     NaN              Thanos' son  Earth-616)
# 16373              NaN     NaN                   Skrull  Earth-616)
# 16374              NaN     NaN               Spiderling  Earth-616)
# 16375              NaN     NaN                Earth-616         NaN
#
# [16376 rows x 15 columns]

# %%
df['ID']= df['ID'].str.split('I').str[0]

# %%
df["ID"] = df["ID"].replace(["No Dual "], "None")

# %%
df.head()
# Out:
#    page_id              name  \
# 0     1678       Spider-Man
# 1     7139  Captain America
# 2    64786        Wolverine
# 3     1868         Iron Man
# 4     2460             Thor
#
#                                              urlslug       ID     ALIGN  \
# 0  https://marvel.fandom.com/wiki/Spider-Man_(Pet...  Secret      Good
# 1  https://marvel.fandom.com/wiki/Captain_America...  Public      Good
# 2  https://marvel.fandom.com/wiki/Wolverine_(Jame...  Public   Neutral
# 3  https://marvel.fandom.com/wiki/Iron_Man_(Antho...  Public      Good
# 4  https://marvel.fandom.com/wiki/Thor_(Thor_Odin...     None     Good
#
#       EYE    HAIR    SEX  GSM    ALIVE  APPEARANCES FIRST APPEARANCE    Year  \
# 0  Hazel   Brown   Male   NaN  Living        4043.0           Aug-62  1962.0
# 1   Blue   White   Male   NaN  Living        3360.0           Mar-41  1941.0
# 2   Blue   Black   Male   NaN  Living        3061.0           Oct-74  1974.0
# 3   Blue   Black   Male   NaN  Living        2961.0           Mar-63  1963.0
# 4   Blue   Blond   Male   NaN  Living        2258.0           Nov-50  1950.0
#
#            Secret_Identity Origin
# 0             Peter Parker    NaN
# 1            Steven Rogers    NaN
# 2  James \"Logan\" Howlett    NaN
# 3   Anthony \"Tony\" Stark    NaN
# 4             Thor Odinson    NaN

# %%
def see_possible_categories(col):
    return df.groupby(col).sum()
     
see_possible_categories("ID")
# Out:
#                           page_id  APPEARANCES        Year
# ID
# Known to Authorities       785553       1116.0     29893.0
# None                    720142592      41215.0   3165853.0
# Public                 1613083818     100208.0   8657706.0
# Secret                 1531859636     102871.0  11876655.0

# %% [markdown]
# ## Some data is in the wrong format. For example, Year and APPEARANCES are floats but they really should be ints (as you cannot have a non-int number of appearances).

# %%
df["Year"]= df["Year"].astype('Int64')

# %%
df["APPEARANCES"]= df["APPEARANCES"].astype('Int64')

# %%
df.head(50)
# Out:
#     page_id                     name  \
# 0      1678              Spider-Man
# 1      7139         Captain America
# 2     64786               Wolverine
# 3      1868                Iron Man
# 4      2460                    Thor
# 5      2458          Benjamin Grimm
# 6      2166           Reed Richards
# 7      1833                    Hulk
# 8     29481           Scott Summers
# 9      1837          Jonathan Storm
# 10    15725             Henry McCoy
# 11     1863             Susan Storm
# 12     7823          Namor McKenzie
# 13     2614            Ororo Munroe
# 14     1803          Clinton Barton
# 15     1396         Matthew Murdock
# 16    55534         Stephen Strange
# 17     1978        Mary Jane Watson
# 18     1872      John Jonah Jameson
# 19    35350            Robert Drake
# 20     1557               Henry Pym
# 21    65255          Charles Xavier
# 22     1073  Warren Worthington III
# 23     1346          Piotr Rasputin
# 24     2512          Wanda Maximoff
# 25     1671           Nicholas Fury
# 26     1976          Janet van Dyne
# 27    65219               Jean Grey
# 28     6545        Natalia Romanova
# 29     2223             Kurt Wagner
# 30     2414                  Vision
# 31     8650              May Reilly
# 32     2527         Katherine Pryde
# 33     1970           Carol Danvers
# 34    37690        Jennifer Walters
# 35     3765              Emma Frost
# 36     2312            Frank Castle
# 37     1265               Luke Cage
# 38     1677                   Rogue
# 39    25222                   Conan
# 40     6537        Joseph Robertson
# 41     1592         Pietro Maximoff
# 42     1818                Hercules
# 43     1448         Victor von Doom
# 44     2081          Max Eisenhardt
# 45     2307      Elizabeth Braddock
# 46     2556             Norrin Radd
# 47     1740           Norman Osborn
# 48     8651         Eugene Thompson
# 49     2009          Simon Williams
#
#                                               urlslug       ID     ALIGN  \
# 0   https://marvel.fandom.com/wiki/Spider-Man_(Pet...  Secret      Good
# 1   https://marvel.fandom.com/wiki/Captain_America...  Public      Good
# 2   https://marvel.fandom.com/wiki/Wolverine_(Jame...  Public   Neutral
# 3   https://marvel.fandom.com/wiki/Iron_Man_(Antho...  Public      Good
# 4   https://marvel.fandom.com/wiki/Thor_(Thor_Odin...     None     Good
# 5   https://marvel.fandom.com/wiki/Benjamin_Grimm_...  Public      Good
# 6   https://marvel.fandom.com/wiki/Reed_Richards_(...  Public      Good
# 7   https://marvel.fandom.com/wiki/Hulk_(Robert_Br...  Public      Good
# 8   https://marvel.fandom.com/wiki/Scott_Summers_(...  Public   Neutral
# 9   https://marvel.fandom.com/wiki/Jonathan_Storm_...  Public      Good
# 10  https://marvel.fandom.com/wiki/Henry_McCoy_(Ea...  Public      Good
# 11  https://marvel.fandom.com/wiki/Susan_Storm_(Ea...  Public      Good
# 12  https://marvel.fandom.com/wiki/Namor_McKenzie_...     None  Neutral
# 13  https://marvel.fandom.com/wiki/Ororo_Munroe_(E...  Public      Good
# 14  https://marvel.fandom.com/wiki/Clinton_Barton_...  Public      Good
# 15  https://marvel.fandom.com/wiki/Matthew_Murdock...  Public      Good
# 16  https://marvel.fandom.com/wiki/Stephen_Strange...  Public      Good
# 17  https://marvel.fandom.com/wiki/Mary_Jane_Watso...     None     Good
# 18  https://marvel.fandom.com/wiki/John_Jonah_Jame...     None  Neutral
# 19  https://marvel.fandom.com/wiki/Robert_Drake_(E...  Secret      Good
# 20  https://marvel.fandom.com/wiki/Henry_Pym_(Eart...  Public      Good
# 21  https://marvel.fandom.com/wiki/Charles_Xavier_...  Public      Good
# 22  https://marvel.fandom.com/wiki/Warren_Worthing...  Public      Good
# 23  https://marvel.fandom.com/wiki/Piotr_Rasputin_...  Secret      Good
# 24  https://marvel.fandom.com/wiki/Wanda_Maximoff_...  Public      Good
# 25  https://marvel.fandom.com/wiki/Nicholas_Fury_(...     None  Neutral
# 26  https://marvel.fandom.com/wiki/Janet_van_Dyne_...  Public      Good
# 27  https://marvel.fandom.com/wiki/Jean_Grey_(Eart...  Public      Good
# 28  https://marvel.fandom.com/wiki/Natalia_Romanov...  Public      Good
# 29  https://marvel.fandom.com/wiki/Kurt_Wagner_(Ea...  Secret      Good
# 30  https://marvel.fandom.com/wiki/Vision_(Earth-616)  Secret      Good
# 31  https://marvel.fandom.com/wiki/May_Reilly_(Ear...     None     Good
# 32  https://marvel.fandom.com/wiki/Katherine_Pryde...  Secret      Good
# 33  https://marvel.fandom.com/wiki/Carol_Danvers_(...  Public      Good
# 34  https://marvel.fandom.com/wiki/Jennifer_Walter...  Public      Good
# 35  https://marvel.fandom.com/wiki/Emma_Frost_(Ear...  Public   Neutral
# 36  https://marvel.fandom.com/wiki/Frank_Castle_(E...  Public   Neutral
# 37  https://marvel.fandom.com/wiki/Luke_Cage_(Eart...     None     Good
# 38  https://marvel.fandom.com/wiki/Rogue_(Anna_Mar...  Secret      Good
# 39   https://marvel.fandom.com/wiki/Conan_(Earth-616)     None  Neutral
# 40  https://marvel.fandom.com/wiki/Joseph_Robertso...     None     Good
# 41  https://marvel.fandom.com/wiki/Pietro_Maximoff...  Public      Good
# 42  https://marvel.fandom.com/wiki/Hercules_(Earth...     None     Good
# 43  https://marvel.fandom.com/wiki/Victor_von_Doom...  Public       Evil
# 44  https://marvel.fandom.com/wiki/Max_Eisenhardt_...  Public   Neutral
# 45  https://marvel.fandom.com/wiki/Elizabeth_Bradd...  Secret   Neutral
# 46  https://marvel.fandom.com/wiki/Norrin_Radd_(Ea...  Public      Good
# 47  https://marvel.fandom.com/wiki/Norman_Osborn_(...  Public       Evil
# 48  https://marvel.fandom.com/wiki/Eugene_Thompson...  Secret      Good
# 49  https://marvel.fandom.com/wiki/Simon_Williams_...  Public      Good
#
#         EYE               HAIR      SEX                  GSM      ALIVE  \
# 0    Hazel              Brown     Male                   NaN    Living
# 1     Blue              White     Male                   NaN    Living
# 2     Blue              Black     Male                   NaN    Living
# 3     Blue              Black     Male                   NaN    Living
# 4     Blue              Blond     Male                   NaN    Living
# 5     Blue                 No     Male                   NaN    Living
# 6    Brown              Brown     Male                   NaN    Living
# 7    Brown              Brown     Male                   NaN    Living
# 8    Brown              Brown     Male                   NaN    Living
# 9     Blue              Blond     Male                   NaN    Living
# 10    Blue               Blue     Male                   NaN    Living
# 11    Blue              Blond   Female                   NaN    Living
# 12   Green              Black     Male                   NaN    Living
# 13    Blue              White   Female                   NaN    Living
# 14    Blue              Blond     Male                   NaN    Living
# 15    Blue                Red     Male                   NaN    Living
# 16    Grey              Black     Male                   NaN    Living
# 17   Green                Red   Female                   NaN    Living
# 18    Blue              Black     Male                   NaN    Living
# 19   Brown              Brown     Male                   NaN    Living
# 20    Blue              Blond     Male                   NaN    Living
# 21    Blue                Bald    Male                   NaN  Deceased
# 22    Blue              Blond     Male                   NaN    Living
# 23    Blue              Black     Male                   NaN    Living
# 24   Green              Brown   Female                   NaN    Living
# 25   Brown              Brown     Male                   NaN    Living
# 26    Blue             Auburn   Female                   NaN    Living
# 27   Green                Red   Female                   NaN  Deceased
# 28   Green                Red   Female   Bisexual Characters    Living
# 29  Yellow               Blue     Male                   NaN    Living
# 30    Gold                 No     Male                   NaN    Living
# 31    Blue               Grey   Female                   NaN    Living
# 32   Hazel              Brown   Female                   NaN    Living
# 33    Blue              Blond   Female                   NaN    Living
# 34   Green              Brown   Female                   NaN    Living
# 35    Blue              Brown   Female                   NaN    Living
# 36    Blue              Black     Male                   NaN    Living
# 37   Brown              Black     Male                   NaN    Living
# 38   Green             Auburn   Female                   NaN    Living
# 39    Blue              Black     Male                   NaN    Living
# 40   Brown              White     Male                   NaN    Living
# 41    Blue             Silver     Male                   NaN    Living
# 42    Blue              Brown     Male   Bisexual Characters    Living
# 43   Brown              Brown     Male                   NaN    Living
# 44    Grey                Bald    Male                   NaN    Living
# 45    Blue             Purple   Female   Bisexual Characters    Living
# 46    Blue                Bald    Male                   NaN    Living
# 47    Blue             Auburn     Male                   NaN    Living
# 48    Blue   Strawberry Blond     Male                   NaN    Living
# 49     Red               Grey     Male                   NaN    Living
#
#     APPEARANCES FIRST APPEARANCE  Year          Secret_Identity      Origin
# 0          4043           Aug-62  1962             Peter Parker         NaN
# 1          3360           Mar-41  1941            Steven Rogers         NaN
# 2          3061           Oct-74  1974  James \"Logan\" Howlett         NaN
# 3          2961           Mar-63  1963   Anthony \"Tony\" Stark         NaN
# 4          2258           Nov-50  1950             Thor Odinson         NaN
# 5          2255           Nov-61  1961                Earth-616         NaN
# 6          2072           Nov-61  1961                Earth-616         NaN
# 7          2017           May-62  1962      Robert Bruce Banner         NaN
# 8          1955           Sep-63  1963                Earth-616         NaN
# 9          1934           Nov-61  1961                Earth-616         NaN
# 10         1825           Sep-63  1963                Earth-616         NaN
# 11         1713           Nov-61  1961                Earth-616         NaN
# 12         1528              NaN  <NA>                Earth-616         NaN
# 13         1512           May-75  1975                Earth-616         NaN
# 14         1394           Sep-64  1964                Earth-616         NaN
# 15         1338           Apr-64  1964                Earth-616         NaN
# 16         1307           Jul-63  1963                Earth-616         NaN
# 17         1304           Jun-65  1965                Earth-616         NaN
# 18         1266           Mar-63  1963                Earth-616         NaN
# 19         1265           Sep-63  1963                Earth-616         NaN
# 20         1237           Jan-62  1962                Earth-616         NaN
# 21         1233           Sep-63  1963                Earth-616         NaN
# 22         1230           Sep-63  1963                Earth-616         NaN
# 23         1162           May-75  1975                Earth-616         NaN
# 24         1161           Mar-64  1964                Earth-616         NaN
# 25         1137           May-63  1963                Earth-616         NaN
# 26         1120           Jun-63  1963                Earth-616         NaN
# 27         1107           Sep-63  1963                Earth-616         NaN
# 28         1050           Apr-64  1964                Earth-616         NaN
# 29         1047           May-75  1975                Earth-616         NaN
# 30         1007           Oct-68  1968                Earth-616         NaN
# 31         1000           Aug-62  1962                Earth-616         NaN
# 32          886           Jan-80  1980                Earth-616         NaN
# 33          881           Mar-68  1968                Earth-616         NaN
# 34          881           Feb-80  1980                Earth-616         NaN
# 35          880           Jan-80  1980                Earth-616         NaN
# 36          878           Feb-74  1974                Earth-616         NaN
# 37          856           Jun-72  1972                Earth-616         NaN
# 38          850              NaN  <NA>               Anna Marie  Earth-616)
# 39          787           Oct-70  1970                Earth-616         NaN
# 40          752           Aug-67  1967                Earth-616         NaN
# 41          740           Mar-64  1964                Earth-616         NaN
# 42          725           Oct-65  1965                Earth-616         NaN
# 43          721           Jul-62  1962                Earth-616         NaN
# 44          709           Sep-63  1963                Earth-616         NaN
# 45          708           Dec-76  1976                Earth-616         NaN
# 46          696           Mar-66  1966                Earth-616         NaN
# 47          692           Jul-64  1964                Earth-616         NaN
# 48          689           Aug-62  1962                Earth-616         NaN
# 49          686           Oct-64  1964                Earth-616         NaN

# %%
# if df["Year"] == "<NA>":
#     df["Year"] == df["APPEARANCES"]
