# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 23 Lab</h1>
# </div>

# %% [markdown]
# # Exercise 1
#
# Plot one chart using matplotlib (OOP-style) using the following data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../datasets/GOOG.csv')
df
# Out:
#             Date        Open        High         Low       Close   Volume  \
# 0     2015-12-31  769.500000  769.500000  758.340027  758.880005  1489600
# 1     2015-12-30  776.599976  777.599976  766.900024  771.000000  1293300
# 2     2015-12-29  766.690002  779.979980  766.429993  776.599976  1765000
# 3     2015-12-28  752.919983  762.989990  749.520020  762.510010  1515300
# 4     2015-12-24  749.549988  751.349976  746.619995  748.400024   527200
# ...          ...         ...         ...         ...         ...      ...
# 1253  2011-01-07  615.911064  618.251043  610.131047  616.441059  4218100
# 1254  2011-01-06  610.681075  618.431037  610.051036  613.501059  4131000
# 1255  2011-01-05  600.071002  610.331074  600.051030  609.071056  5083500
# 1256  2011-01-04  605.621034  606.181048  600.121055  602.121019  3662600
# 1257  2011-01-03  596.481052  605.591014  596.481052  604.351030  4748100
#
#        Adj Close
# 0     758.880005
# 1     771.000000
# 2     776.599976
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Adj Close  1258 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
sns.pairplot(df)

# %%
df1= df["Date"][0:20]
df2 = df["Close"][0:20]
df3 = df["Open"][0:20]

# %%
fig, ax = plt.subplots(figsize=(16, 6))  # Create a figure and an axes.
ax.plot(df1, df2, label='Close') 
ax.plot(df1, df3, label='Open')  
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[0, 19], xlabel='Dates', ylabel='Values',
       title='Googles Opening and Closing Stats for 20 day range')
ax.legend()
plt.show()

# %%
#or instead of saving into a new df refer to the columns
dates = tuple([i for i in df["Date"].value_counts().keys()])[:20]
type(dates)
# Out:
# tuple

# %%
values = df[["Open", "High", "Low", "Close"]][:20]
type(values)
# Out:
# pandas.core.frame.DataFrame

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.plot(dates,values)
ax.set_xlabel("Date")
ax.set_ylabel("Values")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[0, 19], title='Googles Opening and Closing Stats for 20 day range')
ax.legend(["Open", "High", "Low", "Close"])
plt.show()

# %% [markdown]
# # Exercise 2
#
# Perform some initial exploratory analysis to the following dataframe. Then plot two or more charts related to the data.

# %%
df_s = pd.read_csv('../datasets/SHSAT-Registrations-and-Testers.csv')
df_s
# Out:
#         DBN                            School name  Year of SHST  Grade level  \
# 0    05M046                 P.S. 046 Arthur Tappan          2013            8
# 1    05M046                 P.S. 046 Arthur Tappan          2014            8
# 2    05M046                 P.S. 046 Arthur Tappan          2015            8
# 3    05M046                 P.S. 046 Arthur Tappan          2016            8
# 4    05M123               P.S. 123 Mahalia Jackson          2013            8
# ..      ...                                    ...           ...          ...
# 135  84M709  Harlem Village Academy Charter School          2016            9
# 136  84M726  KIPP STAR College Prep Charter School          2013            8
# 137  84M726  KIPP STAR College Prep Charter School          2014            8
# 138  84M726  KIPP STAR College Prep Charter School          2015            8
# 139  84M726  KIPP STAR College Prep Charter School          2016            8
#
# ...

# %%
df_s.describe()
# Out:
#        Year of SHST  Grade level  Enrollment on 10/31  \
# count    140.000000   140.000000           140.000000
# mean    2014.542857     8.392857            91.971429
# std        1.121224     0.490139            47.494027
# min     2013.000000     8.000000            17.000000
# 25%     2014.000000     8.000000            62.750000
# 50%     2015.000000     8.000000            86.000000
# 75%     2016.000000     9.000000           113.000000
# max     2016.000000     9.000000           344.000000
#
#        Number of students who registered for the SHSAT  \
# count                                       140.000000
# mean                                         19.071429
# std                                          23.280165
# min                                           0.000000
# 25%                                           2.000000
# 50%                                          12.000000
# 75%                                          26.000000
# ...

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 7 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   DBN                                              140 non-null    object
#  1   School name                                      140 non-null    object
#  2   Year of SHST                                     140 non-null    int64
#  3   Grade level                                      140 non-null    int64
#  4   Enrollment on 10/31                              140 non-null    int64
#  5   Number of students who registered for the SHSAT  140 non-null    int64
#  6   Number of students who took the SHSAT            140 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 7.8+ KB

# %%
df_s["School name"].unique()
# Out:
# array(['P.S. 046 Arthur Tappan', 'P.S. 123 Mahalia Jackson',
#        'P.S. 129 John H. Finley', 'Eagle Academy for Young Men of Harlem',
#        'The Urban Assembly School for Global Commerce',
#        'P.S. 161 Pedro Albizu Campos',
#        'I.S. M286 Renaissance Leadership Academy',
#        'Urban Assembly Academy for Future Leaders', 'KAPPA IV',
#        'Mott Hall High School', 'Columbia Secondary School',
#        'Academy for Social Action: A College Board School',
#        'Academy for Social Action',
#        'Urban Assembly School for the Performing Arts',
#        'The Urban Assembly Institute for New Technologies',
#        'Choir Academy of Harlem', 'Frederick Douglass Academy',
#        'New Design Middle School',
#        'Thurgood Marshall Academy for Learning and Social Change',
#        'High School for Mathematics, Science and Engineering at City College',
#        'Democracy Prep Endurance Charter School',
# ...

# %%
df_s["Year of SHST"].unique()
# Out:
# array([2013, 2014, 2015, 2016], dtype=int64)

# %% [raw]
# #using matplotlib in pandas
# ax = df_s.groupby('Year of SHST')[['Enrollment on 10/31', 'Number of students who registered for the SHSAT', 'Number of students who took the SHSAT']].sum().sort_values(by='Enrollment on 10/31',ascending=False).plot.barh(stacked=True, figsize=(15,9))
# ax.set_ylabel("Year of SHST")
# ax.set_xlabel("Number of students/Enrollment")
# ax.set_title("Records of students SHSAT by Year")
# #plt.legend(loc='upper right')
# plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#plt.style.use('tableau-colorblind10')  #not sure why the style doesn't get applied
fig, ax = plt.subplots(figsize=(8, 11))
#labels = ax.get_xticklabels()
ax.barh(df_s["School name"], df_s['Number of students who took the SHSAT'])
ax.set(xlim = [0, 50], xlabel='Number of students who took the SHSAT', ylabel='School name',
       title='Number of Students who took the SHST by School')
plt.show()

# %%
st_mean = np.mean(df_s['Number of students who took the SHSAT'])

# %%
plt.title('Number of Students who took the SHSAT by YEAR')
plt.barh(df_s['Year of SHST'], df_s['Number of students who took the SHSAT'])
plt.xlabel('Number students')
plt.ylabel('Year') 
plt.yticks([2012, 2013, 2014, 2015, 2016, 2017])
plt.axvline(st_mean, ls='--', color='r')
plt.setp(labels, rotation=45, horizontalalignment='right')
# plt.ylim = [2013, 2016]
# plt.xlim = [0, 50]
plt.show()

# %%
sns.pairplot(df_s)

# %%
df_s.corr()
#potential liner relationship would be Number of students who took the SHSAT and Number of students who registered for the SHSAT
# Out:
#                                                  Year of SHST  Grade level  \
# Year of SHST                                         1.000000     0.054234
# Grade level                                          0.054234     1.000000
# Enrollment on 10/31                                 -0.029023     0.354346
# Number of students who registered for the SHSAT     -0.099892    -0.575594
# Number of students who took the SHSAT               -0.003468    -0.632743
#
#                                                  Enrollment on 10/31  \
# Year of SHST                                               -0.029023
# Grade level                                                 0.354346
# Enrollment on 10/31                                         1.000000
# Number of students who registered for the SHSAT            -0.060419
# Number of students who took the SHSAT                      -0.023242
#
#                                                  Number of students who registered for the SHSAT  \
# ...

# %%
plt.figure(figsize=(8,8))
sns.jointplot(x=df_s['Number of students who registered for the SHSAT'].values, y=df_s['Number of students who took the SHSAT'].values, height=9)
plt.ylabel('Number of students who took the SHSAT')
plt.xlabel('Number of students who registered for the SHSAT')
plt.show()

# %%
X = df_s["Number of students who registered for the SHSAT"]
Y = df_s["Number of students who took the SHSAT"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train.values.reshape(-1,1), y_train.values.reshape(-1,1))
# Out:
# LinearRegression()

# %%
score = reg.score(X_test.values.reshape(-1,1), y_test.values.reshape(-1,1))

# %%
print(f'Score: {score}')
# Out:
# Score: 0.7156521060594279

# %%
x_line = np.arange(100).reshape(-1,1)

ax=sns.regplot(x="Number of students who registered for the SHSAT", y="Number of students who took the SHSAT", data=df_s, fit_reg=True)
plt.plot(x_line, reg.predict(x_line))
m,b = np.polyfit(X,Y,1)
print(m)
print(b)
plt.show()
# Out:
# 0.32631468161484317
# 3.440998572059781

# %%
f"The equation of this line is y={reg.intercept_} + {reg.coef_}x"
# Out:
# 'The equation of this line is y=[3.79638307] + [[0.33308083]]x'

# %% [markdown]
# # Bonus:
# Perform some initial exploratory analysis to the following dataframe. Then plot one chart related to the data. Run a logistic regression on the data to see if you can classify companies (use `Bankrupt?` as your Y variable).

# %%
df_c = pd.read_csv('../datasets/data.csv')
df_c
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
df_c.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %%
df_c.corr()
# Out:
#                                                     Bankrupt?  \
# Bankrupt?                                            1.000000
#  ROA(C) before interest and depreciation before...  -0.260807
#  ROA(A) before interest and % after tax             -0.282941
#  ROA(B) before interest and depreciation after tax  -0.273051
#  Operating Gross Margin                             -0.100043
# ...                                                       ...
#  Liability to Equity                                 0.166812
#  Degree of Financial Leverage (DFL)                  0.010508
#  Interest Coverage Ratio (Interest expense to E...  -0.005509
#  Net Income Flag                                          NaN
#  Equity to Liability                                -0.083048
#
#                                                      ROA(C) before interest and depreciation before interest  \
# Bankrupt?                                                                                   -0.260807
# ...

# %%
sns.heatmap(df_c.corr())

# %%
# X = df_c[['ROA(C) before interest and depreciation before interest', "Operating Profit Rate", 'Degree of Financial Leverage (DFL)']] 
# Y = df_c["Bankrupt?"]


# #not sure which columns to include for X

# %%
# from sklearn.model_selection import train_test_split

# x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.25)

# %%
# from sklearn.linear_model import LogisticRegression

# logReg = LogisticRegression()

# %%
# logReg.fit(x_train,y_train)

# %%
# y_pred = logReg.predict(x_test)

# %%
# y_pred

# %%
# from sklearn.metrics import confusion_matrix
# cnf_matrix = confusion_matrix(y_test, y_pred)
# cnf_matrix

# %%
# import seaborn as sns

# bankrupt_rate = [0,1]

# fig, ax = plt.subplots()
# tick_marks = np.arange(len(bankrupt_rate))
# plt.xticks(tick_marks, bankrupt_rate)
# plt.yticks(tick_marks, bankrupt_rate)
# sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, fmt='g')
# ax.xaxis.set_label_position("top")
# plt.tight_layout()
# plt.title("Confusion Matrix", y=1.1)
# plt.ylabel("Actual Values")
# plt.xlabel("Predicted Values")
# plt.show()

# %%
# from sklearn.metrics import classification_report
# print(classification_report(y_test, y_pred))

# %%
# from sklearn.metrics import accuracy_score, precision_score, recall_score

# print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
# print(f"Precision: {precision_score(y_test,y_pred)}")
# print(f"Recall: {recall_score(y_test,y_pred)}")
