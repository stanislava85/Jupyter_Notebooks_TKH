# %% [markdown]
# # Python Documentation

# %%
help(

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Extended Lab</h1>
# </div>

# %% [markdown]
# ### Question 1:
#
# Explain what data types are in your own words.

# %% [markdown]
# Data types are attributes that tell us what type/kind of value the data will have.

# %% [markdown]
# ## Question 2:
#
# In your own words, explain what a float is and why sometimes it gives an incorrect value.

# %% [markdown]
# A float is a data structure that represents a decimal number.
# There is also a float method that converst a number or a string that contains numbers into a float data type. If the string that we try to convert contains only letters or letters and numbers it will give us an error.

# %% [markdown]
# ### Exercise 1:
#
# Store your first name, in lowercase, in a variable.
# Using that one variable, print your name in lowercase, Titlecase, and UPPERCASE.

# %%
n = "stanislava"
print(n)
print(n.capitalize())
print(n.upper())
# Out:
# stanislava
# Stanislava
# STANISLAVA

# %% [markdown]
# ### Exercise 2:
#
# Find a quote that you like. Store the quote in a variable, with an appropriate introduction such as "Ken Thompson once said, 'One of my most productive days was throwing away 1000 lines of code'". Print the quote 1000 times.

# %%
q = "Someone once said, 'What goes around comes around.'"
print(q * 1000)
# Out:
# Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'What goes around comes around.'Someone once said, 'Wh ...

# %% [markdown]
# ### Exercise 3:
#
# Use python string operations and methods to use the following variables to print this:
#
#     "hello world"

# %%
message_1 = "hELlo"
message_2 = "                              wor"
message_3 = "wbdaloqteldndyrcggzf"

print(message_1.lower() +" "+ message_2.lstrip() + message_3[9:11])
# Out:
# hello world

# %% [markdown]
# ### Exercise 4
#
# Fix the following code so it prints properly

# %%
# Dollar amounts should only have two digits after the decimal
my_float = 3.44444


print("The price is $" + str(round(my_float, 2)))
# Out:
# The price is $3.44

# %%
# Complete the code so it prints your name and what you're learning
name = input("enter your name: ")
language = input("enter the language you are learning: ")
print(name + " is learning " + language)
# Out:
# enter your name: stani
# enter the language you are learning: python
# stani is learning python

# %%
### Exercise 5

first_adjective = input("enter an adjective")
second_adjective = input("enter an adjective")
first_noun = input("enter a noun")
second_noun = input("enter a noun")
first_verb = input("enter a verb")
first_adverb = input("enter a noun")


mad_lib = f"This madlib is very {first_adjective}, just like yours. Thank you for teaching me how to create such a {second_adjective} thing. It is just like a {first_noun}. What else can I say {second_noun}, I just have to keep up and {first_verb} it {first_adverb}."
print(mad_lib)
# Out:
# enter an adjectivenice
# enter an adjectivecool
# enter a nounman
# enter a nounwoman
# enter a verbrun
# enter a nouncat
# This madlib is very nice, just like yours. Thank you for teaching me how to create such a cool thing. It is just like a man. What else can I say woman, I just have to keep up and run it cat.
