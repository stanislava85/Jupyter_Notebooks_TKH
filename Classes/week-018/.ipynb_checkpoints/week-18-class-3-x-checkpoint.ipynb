# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1 >Week 18 Class 2 01/26</h1>
# </div>
#
# ## Objectives for this week:
# * Data Structuring
# * Data Cleanup
#
# ## Todays Agenda
# * Continuing our code along
# * Lab

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1 >Homework Problem</h1>
# </div>

# %% [markdown]
# ## Exercise 3
#
# Given a stream of integers and a window size, calculate the moving average of all integers in the sliding window.
#
# Implement the `MovingAverage` class:
# * `MovingAverage(size)` Initializes the object with the size of the window size.
# * `next(val)` Returns the moving average of the last size values of the stream.
#
# **Example 1:**
# movingAverage = MovingAverage(3);
# movingAverage.next(1); // return 1.0 = 1 / 1
# movingAverage.next(10); // return 5.5 = (1 + 10) / 2
# movingAverage.next(3); // return 4.66667 = (1 + 10 + 3) / 3
# movingAverage.next(5); // return 6.0 = (10 + 3 + 5) / 3

# %%
class MovingAverage(object):
    def __init__(self, size):
        """
        Initialize your data structure here.
        :type size: int
        """
        self.max_size = size
        self.window = []
        

    def next(self, val):
        """
        :type val: int
        :rtype: float
        """
        if len(self.window) == self.max_size:
            self.window.pop(0)
        self.window.append(val)
        return sum(self.window)/len(self.window)  

moving_average = MovingAverage(3)
print(moving_average.next(1))# == 1.0
print(moving_average.next(10))# == 5.5
print(moving_average.next(3))# == 4.666666666666667
print(moving_average.next(5))# == 6.0

try:
    moving_average = MovingAverage(3)
    assert(moving_average.next(1) == 1.0)
    assert(moving_average.next(10) == 5.5)
    assert(moving_average.next(3) == 4.666666666666667)
    assert(moving_average.next(5) == 6.0)
    moving_average = MovingAverage(5)
    assert(moving_average.next(4) == 4.0)
    assert(moving_average.next(1) == 2.5)
    assert(moving_average.next(10) == 5.0)
    assert(moving_average.next(5) == 5.0)
    print("solution is correct")
except AssertionError:
    print("solution is incorrect")
# Out:
# 1.0
# 5.5
# 4.666666666666667
# 6.0
# solution is correct

# %%
from collections import deque

class MovingAverage(object):
    def __init__(self, size):
        """
        Initialize your data structure here.
        :type size: int
        """
        self.window = deque(maxlen=size)
        

    def next(self, val):
        """
        :type val: int
        :rtype: float
        """
        self.window.append(val)
        return sum(self.window)/len(self.window)  

try:
    moving_average = MovingAverage(3)
    assert(moving_average.next(1) == 1.0)
    assert(moving_average.next(10) == 5.5)
    assert(moving_average.next(3) == 4.666666666666667)
    assert(moving_average.next(5) == 6.0)
    moving_average = MovingAverage(5)
    assert(moving_average.next(4) == 4.0)
    assert(moving_average.next(1) == 2.5)
    assert(moving_average.next(10) == 5.0)
    assert(moving_average.next(5) == 5.0)
    print("solution is correct")
except AssertionError:
    print("solution is incorrect")
# Out:
# solution is correct

# %% [markdown]
# **[more on deque](https://docs.python.org/3/library/collections.html#collections.deque)**

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Books</h1>
# </div>

# %% [markdown]
# Start here:
# [Mathematics for Computer Science](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-042j-mathematics-for-computer-science-fall-2010/readings/MIT6_042JF10_notes.pdf)
# [Introduction to Probability](http://www.dartmouth.edu/~chance/teaching_aids/books_articles/probability_book/pdf.html)
# [Statistics](https://upload.wikimedia.org/wikipedia/commons/8/82/Statistics.pdf)
# [Think Stats (using python)](https://greenteapress.com/thinkstats2/thinkstats2.pdf)
# [Think Bayes](https://www.greenteapress.com/thinkbayes/thinkbayes.pdf)
# [Probabilistic Programming and Bayesian Methods for Hackers](https://nbviewer.jupyter.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter1_Introduction/Ch1_Introduction_PyMC3.ipynb)

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Code Along</h1>
#     <h3>Cleaning up dirty data</h3>
# </div>

# %% [markdown]
# Some new things we'll cover in this code along:
#
# [pandas.DataFrame.apply](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html) - applies a function to rows of a col
# [pandas.DataFrame.drop](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html) - drops rows or columns
# [pandas.DataFrame.drop_duplicates](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) - drops duplicates
# [pandas.DataFrame.duplicated](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) - returns True if duplicate
# [pandas.DataFrame.fillna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html) - fills NaN values
# [pandas.merge](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) - merges two dfs

# %% [markdown]
# Importing the libraries we'll be using

# %%
import numpy as np 
import pandas as pd 
import datetime

# %% [markdown]
# Let's open the `ted_talks.csv` file and generate a dataframe. Then we'll check the top of the `df` to see what we have.

# %%
df = pd.read_csv("../datasets/ted_talks.csv")
df.head()
# Out:
#    ID  comments                                        description  duration  \
# 0   0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1   1      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 2   2       265  With the same humor and humanity he exuded in ...       977
# 3   3       124  New York Times columnist David Pogue takes aim...      1286
# 4   4       200  In an emotionally charged talk, MacArthur-winn...      1116
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60       Emma Rob
# 1  TED2006  1140825600         60       Emma Rob
# 2  TED2006  1140825600         43            NaN
# 3  TED2006  1140739200         26            NaN
# 4  TED2006  1140912000         35  Majora Carter
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1  Ken Robinson: Do schools kill creativity?            1      1151367060
# 2       Al Gore: Averting the climate crisis            1      1151367060
# 3              David Pogue: Simplicity sells            1      1151367060
# 4         Majora Carter: Greening the ghetto           -1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4  [{'id': 3, 'name': 'Courageous', 'count': 760}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 3  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
#
#                    speaker_occupation  \
# 0                     Author/educator
# 1                     Author/educator
# 2                    Climate advocate
# 3                Technology columnist
# 4  Activist for environmental justice
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['children', 'creativity', 'culture', 'dance',...
# 2  ['alternative energy', 'cars', 'climate change...
# 3  ['computers', 'entertainment', 'interface desi...
# 4  ['MacArthur grant', 'activism', 'business', 'c...
#
#                          title  \
# 0  Do schools kill creativity?
# 1  Do schools kill creativity?
# 2  Averting the climate crisis
# 3             Simplicity sells
# 4          Greening the ghetto
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 2  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 3  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 4  https://www.ted.com/talks/majora_carter_s_tale...   1697550

# %% [markdown]
# Checking the shape of the `df`

# %%
df.shape
# Out:
# (2555, 18)

# %% [markdown]
# Checking info to see other information (like how much RAM our dataset uses and how many non-null entries we have)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2555 entries, 0 to 2554
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  2555 non-null   int64
#  1   comments            2555 non-null   int64
#  2   description         2555 non-null   object
#  3   duration            2555 non-null   int64
#  4   event               2555 non-null   object
#  5   film_date           2555 non-null   int64
#  6   languages           2555 non-null   int64
#  7   main_speaker        2531 non-null   object
#  8   name                2555 non-null   object
#  9   num_speaker         2555 non-null   int64
#  10  published_date      2555 non-null   int64
#  11  ratings             2555 non-null   object
#  12  related_talks       2555 non-null   object
#  13  speaker_occupation  2549 non-null   object
#  14  tags                2555 non-null   object
#  15  title               2555 non-null   object
#  16  url                 2555 non-null   object
#  17  views               2555 non-null   int64
# dtypes: int64(8), object(10)
# memory usage: 359.4+ KB

# %% [markdown]
# We see we have 2555 rows but 2531 non-null rows for 'main_speaker'. So let's check that out.

# %%
df[df['main_speaker'].isna()][["description", "main_speaker","name"]]
# Out:
#                                            description main_speaker  \
# 2    With the same humor and humanity he exuded in ...          NaN
# 3    New York Times columnist David Pogue takes aim...          NaN
# 13   Jehane Noujaim unveils her 2006 TED Prize wish...          NaN
# 34   Cambridge researcher Aubrey de Grey argues tha...          NaN
# 62   Writer and actor Anna Deavere Smith gives life...          NaN
# 75   Graphic designer Stefan Sagmeister takes the a...          NaN
# 93   Green-minded architect and designer William Mc...          NaN
# 123  Alan Russell studies regenerative medicine -- ...          NaN
# 161  Lawrence Lessig, the Net’s most celebrated law...          NaN
# 191  What if human consciousness isn't the end-all ...          NaN
# 222  Novelist Amy Tan digs deep into the creative p...          NaN
# 237  Around the world right now, one billion people...          NaN
# 249  Benjamin Zander has two infectious passions: c...          NaN
# 268  Chris Abani tells stories of people: People st...          NaN
# 282  Imagine hearing great, departed pianists play ...          NaN
# 318  Humorist John Hodgman rambles through a new st...          NaN
# 362  Reporter Jennifer 8. Lee talks about her hunt ...          NaN
# 444  By analyzing raw data on violent incidents in ...          NaN
# 456  "Bonk" author Mary Roach delves into obscure s...          NaN
# 478  Organ virtuoso Qi Zhang plays her electric ren...          NaN
# 539  Advertising adds value to a product by changin...          NaN
# 591  Legendary jazz musician Herbie Hancock deliver...          NaN
# 670  Some 80 to 90 percent of undersea creatures ma...          NaN
# 721  Lego blocks: playtime mainstay for industrious...          NaN
#
#                                                   name
# 2                 Al Gore: Averting the climate crisis
# 3                        David Pogue: Simplicity sells
# 13       Jehane Noujaim: My wish: A global day of film
# 34              Aubrey de Grey: A roadmap to end aging
# 62        Anna Deavere Smith: Four American characters
# 75              Stefan Sagmeister: Happiness by design
# 93          William McDonough: Cradle to cradle design
# 123  Alan Russell: The potential of regenerative me...
# 161        Lawrence Lessig: Laws that choke creativity
# 191                 Michael Pollan: A plant's-eye view
# 222               Amy Tan: Where does creativity hide?
# 237                 Paul Collier: The "bottom billion"
# 249  Benjamin Zander: The transformative power of c...
# 268                           Chris Abani: On humanity
# 282  John Q. Walker: Great piano performances, recr...
# 318      John Hodgman: Aliens, love -- where are they?
# 362          Jennifer 8. Lee: The hunt for General Tso
# 444               Sean Gourley: The mathematics of war
# 456  Mary Roach: 10 things you didn't know about or...
# 478        Qi Zhang: An electrifying organ performance
# 539       Rory Sutherland: Life lessons from an ad man
# 591                    Herbie Hancock: An all-star set
# 670  Edith Widder: Glowing life in an underwater world
# 721               Hillel Cooperman: Legos for grownups

# %% [markdown]
# Before we fix the "main_speaker" column, let's shrink our dataset by removing duplicates.
# First we need to see how many duplicates we have:

# %%
df['url'].duplicated().sort_values(ascending=False)[:6]
# Out:
# 1       True
# 419     True
# 426     True
# 6       True
# 931     True
# 0      False
# Name: url, dtype: bool

# %%
df[(df['url'].duplicated() == False)]
# Out:
#         ID  comments                                        description  \
# 0        0      4553  Sir Ken Robinson makes an entertaining and pro...
# 2        2       265  With the same humor and humanity he exuded in ...
# 3        3       124  New York Times columnist David Pogue takes aim...
# 4        4       200  In an emotionally charged talk, MacArthur-winn...
# 5        5       593  You've never seen data presented like this. Wi...
# ...    ...       ...                                                ...
# 2550  2549        17  Between 2008 and 2016, the United States depor...
# 2551  2550         6  How can you study Mars without a spaceship? He...
# 2552  2551        10  Science fiction visions of the future show us ...
# 2553  2552        32  In an unmissable talk about race and politics ...
# 2554  2553         8  With more than half of the world population li...
#
#       duration         event   film_date  languages         main_speaker  \
# 0         1164       TED2006  1140825600         60             Emma Rob
# 2          977       TED2006  1140825600         43                  NaN
# 3         1286       TED2006  1140739200         26                  NaN
# 4         1116       TED2006  1140912000         35        Majora Carter
# 5         1190       TED2006  1140566400         48         Hans Rosling
# ...        ...           ...         ...        ...                  ...
# 2550       476       TED2017  1496707200          4     Duarte Geraldino
# 2551       290       TED2017  1492992000          3  Armando Azua-Bustos
# 2552       651       TED2017  1492992000          1       Radhika Nagpal
# 2553      1100  TEDxMileHigh  1499472000          1     Theo E.J. Wilson
# 2554       519       TED2017  1492992000          1    Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 0             Ken Robinson: Do schools kill creativity?            1
# 2                  Al Gore: Averting the climate crisis            1
# 3                         David Pogue: Simplicity sells            1
# 4                    Majora Carter: Greening the ghetto           -1
# 5         Hans Rosling: The best stats you've ever seen            1
# ...                                                 ...          ...
# 2550  Duarte Geraldino: What we're missing in the de...            1
# 2551  Armando Azua-Bustos: The most Martian place on...            1
# 2552  Radhika Nagpal: What intelligent machines can ...            1
# 2553  Theo E.J. Wilson: A black man goes undercover ...            1
# 2554  Karoliina Korppoo: How a video game might help...            1
#
#       published_date                                            ratings  \
# 0         1151367060  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2         1151367060  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3         1151367060  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4         1151367060  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 5         1151440680  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...              ...                                                ...
# 2550      1505851216  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2551      1505919737  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2552      1506006095  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2553      1506024042  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2554      1506092422  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 2     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 3     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 4     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 5     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# ...                                                 ...
# 2550  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2551  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2552  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...
# 2553  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 2554  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                         speaker_occupation  \
# 0                          Author/educator
# 2                         Climate advocate
# 3                     Technology columnist
# 4       Activist for environmental justice
# 5     Global health expert; data visionary
# ...                                    ...
# 2550                            Journalist
# 2551                        Astrobiologist
# 2552                     Robotics engineer
# 2553                   Public intellectual
# 2554                         Game designer
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 2     ['alternative energy', 'cars', 'climate change...
# 3     ['computers', 'entertainment', 'interface desi...
# 4     ['MacArthur grant', 'activism', 'business', 'c...
# 5     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...                                                 ...
# 2550  ['TED Residency', 'United States', 'community'...
# 2551  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2552  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2553  ['Internet', 'TEDx', 'United States', 'communi...
# 2554  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 2                           Averting the climate crisis
# 3                                      Simplicity sells
# 4                                   Greening the ghetto
# 5                       The best stats you've ever seen
# ...                                                 ...
# 2550  What we're missing in the debate about immigra...
# 2551                    The most Martian place on Earth
# 2552  What intelligent machines can learn from a sch...
# 2553       A black man goes undercover in the alt-right
# 2554  How a video game might help us build better ci...
#
#                                                     url     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 2     https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 3     https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 4     https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 5     https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# ...                                                 ...       ...
# 2550  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2551  https://www.ted.com/talks/armando_azua_bustos_...    417470
# 2552  https://www.ted.com/talks/radhika_nagpal_what_...    375647
# 2553  https://www.ted.com/talks/theo_e_j_wilson_a_bl...    419309
# 2554  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
# [2550 rows x 18 columns]

# %%
df[df['url'].duplicated()]
# Out:
#       ID  comments                                        description  \
# 1      1      4553  Sir Ken Robinson makes an entertaining and pro...
# 6      6       593  You've never seen data presented like this. Wi...
# 419  419        50  Singer/songwriter Eddi Reader performs "What Y...
# 426  426       420  Bonnie Bassler discovered that bacteria "talk"...
# 931  930       149  Phyllis Rodriguez and Aicha el-Wafi have a pow...
#
#      duration          event   film_date  languages  \
# 1        1164        TED2006  1140825600         60
# 6        1190        TED2006  1140566400         48
# 419       312        TED2003  1044144000         25
# 426      1094        TED2009  1233878400         39
# 931       594  TEDWomen 2010  1292112000         32
#
#                           main_speaker  \
# 1                             Emma Rob
# 6                         Hans Rosling
# 419                        Eddi Reader
# 426                     Bonnie Bassler
# 931  Aicha el-Wafi + Phyllis Rodriguez
#
#                                                   name  num_speaker  \
# 1            Ken Robinson: Do schools kill creativity?            1
# 6        Hans Rosling: The best stats you've ever seen            1
# 419                     Eddi Reader: "What You've Got"            2
# 426                Bonnie Bassler: How bacteria "talk"            1
# 931  Aicha el-Wafi + Phyllis Rodriguez: The mothers...            1
#
#      published_date                                            ratings  \
# 1        1151367060  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 6        1151440680  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# 419      1176586800  [{'id': 1, 'name': 'Beautiful', 'count': 272},...
# 426      1239152400  [{'id': 22, 'name': 'Fascinating', 'count': 27...
# 931      1304362260  [{'id': 10, 'name': 'Inspiring', 'count': 385}...
#
#                                          related_talks  \
# 1    [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 6    [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# 419  [{'id': 110, 'hero': 'https://pe.tedcdn.com/im...
# 426  [{'id': 519, 'hero': 'https://pe.tedcdn.com/im...
# 931  [{'id': 968, 'hero': 'https://pe.tedcdn.com/im...
#
#                        speaker_occupation  \
# 1                         Author/educator
# 6    Global health expert; data visionary
# 419                     Singer/songwriter
# 426                   Molecular biologist
# 931                          9/11 mothers
#
#                                                   tags  \
# 1    ['children', 'creativity', 'culture', 'dance',...
# 6    ['Africa', 'Asia', 'Google', 'demo', 'economic...
# 419  ['composing', 'entertainment', 'guitar', 'musi...
# 426  ['MacArthur grant', 'bacteria', 'biology', 'co...
# 931  ['culture', 'friendship', 'global issues', 'pa...
#
#                                              title  \
# 1                      Do schools kill creativity?
# 6                  The best stats you've ever seen
# 419                              "What You've Got"
# 426                            How bacteria "talk"
# 931  The mothers who found forgiveness, friendship
#
#                                                    url     views
# 1    https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 6    https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# 419  https://www.ted.com/talks/eddi_reader_sings_ab...    428351
# 426  https://www.ted.com/talks/bonnie_bassler_on_ho...   2192828
# 931  https://www.ted.com/talks/9_11_healing_the_mot...    820976

# %% [markdown]
# Then we'll drop the duplicates using the `df.drop_duplicates` method.
#
# Remember, the keyword `inplace` means it will mutate the original `df`.

# %%
help(df.drop_duplicates)
# Out:
# Help on method drop_duplicates in module pandas.core.frame:
#
# drop_duplicates(subset: 'Optional[Union[Hashable, Sequence[Hashable]]]' = None, keep: 'Union[str, bool]' = 'first', inplace: 'bool' = False, ignore_index: 'bool' = False) -> 'Optional[DataFrame]' method of pandas.core.frame.DataFrame instance
#     Return DataFrame with duplicate rows removed.
#
#     Considering certain columns is optional. Indexes, including time indexes
#     are ignored.
#
#     Parameters
#     ----------
#     subset : column label or sequence of labels, optional
#         Only consider certain columns for identifying duplicates, by
#         default use all of the columns.
#     keep : {'first', 'last', False}, default 'first'
#         Determines which duplicates (if any) to keep.
#         - ``first`` : Drop duplicates except for the first occurrence.
#         - ``last`` : Drop duplicates except for the last occurrence.
#         - False : Drop all duplicates.
#     inplace : bool, default False
#         Whether to drop duplicates in place or to return a copy.
#     ignore_index : bool, default False
#         If True, the resulting axis will be labeled 0, 1, …, n - 1.
#
#         .. versionadded:: 1.0.0
#
#     Returns
#     -------
#     DataFrame or None
#         DataFrame with duplicates removed or None if ``inplace=True``.
#
#     See Also
#     --------
#     DataFrame.value_counts: Count unique combinations of columns.
#
#     Examples
#     --------
#     Consider dataset containing ramen rating.
#
#     >>> df = pd.DataFrame({
#     ...     'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
#     ...     'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
#     ...     'rating': [4, 4, 3.5, 15, 5]
#     ... })
#     >>> df
#         brand style  rating
#     0  Yum Yum   cup     4.0
#     1  Yum Yum   cup     4.0
#     2  Indomie   cup     3.5
#     3  Indomie  pack    15.0
#     4  Indomie  pack     5.0
#
#     By default, it removes duplicate rows based on all columns.
#
#     >>> df.drop_duplicates()
#         brand style  rating
#     0  Yum Yum   cup     4.0
#     2  Indomie   cup     3.5
#     3  Indomie  pack    15.0
#     4  Indomie  pack     5.0
#
#     To remove duplicates on specific column(s), use ``subset``.
#
#     >>> df.drop_duplicates(subset=['brand'])
#         brand style  rating
#     0  Yum Yum   cup     4.0
#     2  Indomie   cup     3.5
#
#     To remove duplicates and keep last occurrences, use ``keep``.
#
#     >>> df.drop_duplicates(subset=['brand', 'style'], keep='last')
#         brand style  rating
#     1  Yum Yum   cup     4.0
#     2  Indomie   cup     3.5
#     4  Indomie  pack     5.0

# %%
df.drop_duplicates('url', inplace=True)

# %% [markdown]
# Next we'll drop the `ID` column as it's unnecessary

# %%
df.drop('ID', axis=1, inplace=True)

# %% [markdown]
# If we look at `published_date` and `film_date`, they're formatted as unix timestamps. We might need a human-readable format.
#
# [more on unix timestamps](https://en.wikipedia.org/wiki/Unix_time)

# %%
df[["published_date", "film_date"]]
# Out:
#       published_date   film_date
# 0         1151367060  1140825600
# 2         1151367060  1140825600
# 3         1151367060  1140739200
# 4         1151367060  1140912000
# 5         1151440680  1140566400
# ...              ...         ...
# 2550      1505851216  1496707200
# 2551      1505919737  1492992000
# 2552      1506006095  1492992000
# 2553      1506024042  1499472000
# 2554      1506092422  1492992000
#
# [2550 rows x 2 columns]

# %% [markdown]
# Let's see how we can turn a unix timestamp into a human-readable format

# %%
ts = 1151367060

s = datetime.datetime.fromtimestamp(ts)

s.strftime("%m/%d/%Y, %H:%M:%S")
# Out:
# '06/26/2006, 20:11:00'

# %% [markdown]
# Putting that together, we can create a function that does this for any timestamp

# %%
def transform_date(timestamp):
    _date = datetime.datetime.fromtimestamp(timestamp)
    return _date.strftime("%m/%d/%Y, %H:%M:%S")

# %% [markdown]
# And then we can test it with a random timestamp

# %%
transform_date(1151367060)
# Out:
# '06/26/2006, 20:11:00'

# %% [markdown]
# We can use the `df.apply` method to apply that function to each row of a specific column.

# %%
df['film_date'].apply(transform_date)
# Out:
# 0       02/24/2006, 19:00:00
# 2       02/24/2006, 19:00:00
# 3       02/23/2006, 19:00:00
# 4       02/25/2006, 19:00:00
# 5       02/21/2006, 19:00:00
#                 ...
# 2550    06/05/2017, 20:00:00
# 2551    04/23/2017, 20:00:00
# 2552    04/23/2017, 20:00:00
# 2553    07/07/2017, 20:00:00
# 2554    04/23/2017, 20:00:00
# Name: film_date, Length: 2550, dtype: object

# %% [markdown]
# Seeing that it works, we can now use that `transform_date` method along with `apply` to create two new columns of human-readable timestamps

# %%
df['film_date_hr'] = df['film_date'].apply(transform_date)
df['published_date_hr'] = df['published_date'].apply(transform_date)

# %% [markdown]
# If we wanted to change the ordering of the columns, we can use `df.columns.tolist()` to list our columns and then `df.reindex()` to reindex the columns by passing in a list of columns in the order we want

# %%
df.columns.tolist()
# Out:
# ['comments',
#  'description',
#  'duration',
#  'event',
#  'film_date',
#  'languages',
#  'main_speaker',
#  'name',
#  'num_speaker',
#  'published_date',
#  'ratings',
#  'related_talks',
#  'speaker_occupation',
#  'tags',
#  'title',
#  'url',
#  'views',
#  'film_date_hr',
#  'published_date_hr']

# %%
df = df.reindex(['comments',
 'description',
 'duration',
 'event',
 'film_date',
 'film_date_hr',
 'languages',
 'main_speaker',
 'name',
 'num_speaker',
 'published_date',
 'published_date_hr',
 'ratings',
 'related_talks',
 'speaker_occupation',
 'tags',
 'title',
 'url',
 'views',
],axis=1)

# %% [markdown]
# We can see that works by checking the head of the `df`

# %%
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 2       265  With the same humor and humanity he exuded in ...       977
# 3       124  New York Times columnist David Pogue takes aim...      1286
# 4       200  In an emotionally charged talk, MacArthur-winn...      1116
# 5       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date          film_date_hr  languages   main_speaker  \
# 0  TED2006  1140825600  02/24/2006, 19:00:00         60       Emma Rob
# 2  TED2006  1140825600  02/24/2006, 19:00:00         43            NaN
# 3  TED2006  1140739200  02/23/2006, 19:00:00         26            NaN
# 4  TED2006  1140912000  02/25/2006, 19:00:00         35  Majora Carter
# 5  TED2006  1140566400  02/21/2006, 19:00:00         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 2           Al Gore: Averting the climate crisis            1      1151367060
# 3                  David Pogue: Simplicity sells            1      1151367060
# 4             Majora Carter: Greening the ghetto           -1      1151367060
# 5  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#       published_date_hr                                            ratings  \
# 0  06/26/2006, 20:11:00  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2  06/26/2006, 20:11:00  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3  06/26/2006, 20:11:00  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4  06/26/2006, 20:11:00  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 5  06/27/2006, 16:38:00  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 3  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 5  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 2                      Climate advocate
# 3                  Technology columnist
# 4    Activist for environmental justice
# 5  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 2  ['alternative energy', 'cars', 'climate change...
# 3  ['computers', 'entertainment', 'interface desi...
# 4  ['MacArthur grant', 'activism', 'business', 'c...
# 5  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 2      Averting the climate crisis
# 3                 Simplicity sells
# 4              Greening the ghetto
# 5  The best stats you've ever seen
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 2  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 3  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 4  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 5  https://www.ted.com/talks/hans_rosling_shows_t...  12005869

# %% [markdown]
# Next, we'll fix the durations, which are in seconds, by converting them to mins and rounding the result to 2 places after the decimal

# %%
df['duration'] = round( df['duration'] / 60, 2)

# %% [markdown]
# We'll fix incorrect values for `languages` and `num_speakers` by replacing erroneous values with `1` since we know there's at least one language translated (english) and there's at least one speaker.

# %%
df[df['languages'] == 0]
# Out:
#       comments                                        description  duration  \
# 7          672  Tony Robbins discusses the "invisible forces" ...     21.75
# 42          58  Accepting his 2005 TED Prize, photographer Edw...     34.42
# 49          52  Musician and activist Peter Gabriel shares his...     14.13
# 61         222  Two Pilobolus dancers perform "Symbiosis." Doe...     13.75
# 89          39  A happy song about global warming, from Jill S...      2.72
# ...        ...                                                ...       ...
# 1432       229  Kid President commands you to wake up, listen ...      3.47
# 1472       183  As we move through the world, we have an innat...      6.47
# 1491       126  What color is a mirror? How much does a video ...      7.35
# 2412         5  Grammy-winning Silk Road Ensemble display thei...      6.48
# 2423        11  Sō Percussion creates adventurous compositions...     10.15
#
#               event   film_date          film_date_hr  languages  \
# 7           TED2006  1138838400  02/01/2006, 19:00:00          0
# 42          TED2005  1108598400  02/16/2005, 19:00:00          0
# 49          TED2006  1140652800  02/22/2006, 19:00:00          0
# 61          TED2005  1109289600  02/24/2005, 19:00:00          0
# 89          TED2006  1140912000  02/25/2006, 19:00:00          0
# ...             ...         ...                   ...        ...
# 1432    SoulPancake  1358985600  01/23/2013, 19:00:00          0
# 1472  TEDYouth 2012  1353110400  11/16/2012, 19:00:00          0
# 1491         TED-Ed  1362009600  02/27/2013, 19:00:00          0
# 2412        TED2016  1455494400  02/14/2016, 19:00:00          0
# 2423        TED2016  1455494400  02/14/2016, 19:00:00          0
#
#                 main_speaker  \
# 7               Tony Robbins
# 42          Edward Burtynsky
# 49             Peter Gabriel
# 61                 Pilobolus
# 89               Jill Sobule
# ...                      ...
# 1432           Kid President
# 1472  Katherine Kuchenbecker
# 1491         Michael Stevens
# 2412      Silk Road Ensemble
# 2423           Sō Percussion
#
#                                                    name  num_speaker  \
# 7                    Tony Robbins: Why we do what we do            0
# 42    Edward Burtynsky: My wish: Manufactured landsc...            1
# 49        Peter Gabriel: Fight injustice with raw video            1
# 61                    Pilobolus: A dance of "Symbiosis"            1
# 89    Jill Sobule: Global warming's theme song, "Man...            1
# ...                                                 ...          ...
# 1432      Kid President: I think we all need a pep talk            1
# 1472    Katherine Kuchenbecker: The technology of touch            1
# 1491      Michael Stevens: How much does a video weigh?            1
# 2412                    Silk Road Ensemble: "Turceasca"            1
# 2423        Sō Percussion: "Music for Wood and Strings"            1
#
#       published_date     published_date_hr  \
# 7         1151440680  06/27/2006, 16:38:00
# 42        1162253460  10/30/2006, 19:11:00
# 49        1165363860  12/05/2006, 19:11:00
# 61        1170979860  02/08/2007, 19:11:00
# 89        1175819400  04/05/2007, 20:30:00
# ...              ...                   ...
# 1432      1359734822  02/01/2013, 11:07:02
# 1472      1364569190  03/29/2013, 10:59:50
# 1491      1366815569  04/24/2013, 10:59:29
# 2412      1489759215  03/17/2017, 10:00:15
# 2423      1490963646  03/31/2017, 08:34:06
#
#                                                 ratings  \
# 7     [{'id': 7, 'name': 'Funny', 'count': 1102}, {'...
# 42    [{'id': 1, 'name': 'Beautiful', 'count': 106},...
# 49    [{'id': 3, 'name': 'Courageous', 'count': 180}...
# 61    [{'id': 1, 'name': 'Beautiful', 'count': 1810}...
# 89    [{'id': 9, 'name': 'Ingenious', 'count': 45}, ...
# ...                                                 ...
# 1432  [{'id': 10, 'name': 'Inspiring', 'count': 771}...
# 1472  [{'id': 9, 'name': 'Ingenious', 'count': 150},...
# 1491  [{'id': 22, 'name': 'Fascinating', 'count': 17...
# 2412  [{'id': 1, 'name': 'Beautiful', 'count': 80}, ...
# 2423  [{'id': 21, 'name': 'Unconvincing', 'count': 8...
#
#                                           related_talks  \
# 7     [{'id': 229, 'hero': 'https://pe.tedcdn.com/im...
# 42    [{'id': 279, 'hero': 'https://pe.tedcdn.com/im...
# 49    [{'id': 75, 'hero': 'https://pe.tedcdn.com/ima...
# 61    [{'id': 40, 'hero': 'https://pe.tedcdn.com/ima...
# 89    [{'id': 222, 'hero': 'https://pe.tedcdn.com/im...
# ...                                                 ...
# 1432  [{'id': 815, 'hero': 'https://pe.tedcdn.com/im...
# 1472  [{'id': 1692, 'hero': 'https://pe.tedcdn.com/i...
# 1491  [{'id': 1386, 'hero': 'https://pe.tedcdn.com/i...
# 2412  [{'id': 2611, 'hero': 'https://pe.tedcdn.com/i...
# 2423  [{'id': 2538, 'hero': 'https://pe.tedcdn.com/i...
#
#                                speaker_occupation  \
# 7     Life coach; expert in leadership psychology
# 42                                   Photographer
# 49                             Musician, activist
# 61                                  Dance company
# 89                              Singer/songwriter
# ...                                           ...
# 1432                                     Inspirer
# 1472                          Mechanical engineer
# 1491                             YouTube educator
# 2412                            Musical explorers
# 2423                          Percussion ensemble
#
#                                                    tags  \
# 7     ['business', 'culture', 'entertainment', 'goal...
# 42    ['TED Prize', 'art', 'cities', 'culture', 'des...
# 49    ['TED Brain Trust', 'activism', 'art', 'collab...
# 61    ['dance', 'entertainment', 'nature', 'performa...
# 89    ['climate change', 'environment', 'guitar', 'm...
# ...                                                 ...
# 1432                    ['children', 'comedy', 'humor']
# 1472          ['TEDYouth', 'engineering', 'technology']
# 1491  ['Internet', 'TED-Ed', 'computers', 'humor', '...
# 2412      ['art', 'live music', 'music', 'performance']
# 2423  ['live music', 'music', 'performance', 'perfor...
#
#                                                   title  \
# 7                                  Why we do what we do
# 42    My wish: Manufactured landscapes and green edu...
# 49                       Fight injustice with raw video
# 61                               A dance of "Symbiosis"
# 89    Global warming's theme song, "Manhattan in Jan...
# ...                                                 ...
# 1432                     I think we all need a pep talk
# 1472                            The technology of touch
# 1491                       How much does a video weigh?
# 2412                                        "Turceasca"
# 2423                       "Music for Wood and Strings"
#
#                                                     url     views
# 7     https://www.ted.com/talks/tony_robbins_asks_wh...  20685401
# 42    https://www.ted.com/talks/edward_burtynsky_on_...    975107
# 49    https://www.ted.com/talks/peter_gabriel_fights...    904215
# 61    https://www.ted.com/talks/pilobolus_perform_sy...   3051507
# 89    https://www.ted.com/talks/jill_sobule_sings_to...    591379
# ...                                                 ...       ...
# 1432  https://www.ted.com/talks/kid_president_i_thin...    828203
# 1472  https://www.ted.com/talks/katherine_kuchenbeck...    274986
# 1491  https://www.ted.com/talks/how_much_does_a_vide...    195899
# 2412  https://www.ted.com/talks/silk_road_ensemble_t...    640734
# 2423  https://www.ted.com/talks/so_percussion_music_...    767660
#
# [90 rows x 19 columns]

# %%
df['languages'].replace(0, 1, inplace=True)
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...     19.40
# 2          265  With the same humor and humanity he exuded in ...     16.28
# 3          124  New York Times columnist David Pogue takes aim...     21.43
# 4          200  In an emotionally charged talk, MacArthur-winn...     18.60
# 5          593  You've never seen data presented like this. Wi...     19.83
# ...        ...                                                ...       ...
# 2550        17  Between 2008 and 2016, the United States depor...      7.93
# 2551         6  How can you study Mars without a spaceship? He...      4.83
# 2552        10  Science fiction visions of the future show us ...     10.85
# 2553        32  In an unmissable talk about race and politics ...     18.33
# 2554         8  With more than half of the world population li...      8.65
#
#              event   film_date          film_date_hr  languages  \
# 0          TED2006  1140825600  02/24/2006, 19:00:00         60
# 2          TED2006  1140825600  02/24/2006, 19:00:00         43
# 3          TED2006  1140739200  02/23/2006, 19:00:00         26
# 4          TED2006  1140912000  02/25/2006, 19:00:00         35
# 5          TED2006  1140566400  02/21/2006, 19:00:00         48
# ...            ...         ...                   ...        ...
# 2550       TED2017  1496707200  06/05/2017, 20:00:00          4
# 2551       TED2017  1492992000  04/23/2017, 20:00:00          3
# 2552       TED2017  1492992000  04/23/2017, 20:00:00          1
# 2553  TEDxMileHigh  1499472000  07/07/2017, 20:00:00          1
# 2554       TED2017  1492992000  04/23/2017, 20:00:00          1
#
#              main_speaker                                               name  \
# 0                Emma Rob          Ken Robinson: Do schools kill creativity?
# 2                     NaN               Al Gore: Averting the climate crisis
# 3                     NaN                      David Pogue: Simplicity sells
# 4           Majora Carter                 Majora Carter: Greening the ghetto
# 5            Hans Rosling      Hans Rosling: The best stats you've ever seen
# ...                   ...                                                ...
# 2550     Duarte Geraldino  Duarte Geraldino: What we're missing in the de...
# 2551  Armando Azua-Bustos  Armando Azua-Bustos: The most Martian place on...
# 2552       Radhika Nagpal  Radhika Nagpal: What intelligent machines can ...
# 2553     Theo E.J. Wilson  Theo E.J. Wilson: A black man goes undercover ...
# 2554    Karoliina Korppoo  Karoliina Korppoo: How a video game might help...
#
#       num_speaker  published_date     published_date_hr  \
# 0               1      1151367060  06/26/2006, 20:11:00
# 2               1      1151367060  06/26/2006, 20:11:00
# 3               1      1151367060  06/26/2006, 20:11:00
# 4              -1      1151367060  06/26/2006, 20:11:00
# 5               1      1151440680  06/27/2006, 16:38:00
# ...           ...             ...                   ...
# 2550            1      1505851216  09/19/2017, 16:00:16
# 2551            1      1505919737  09/20/2017, 11:02:17
# 2552            1      1506006095  09/21/2017, 11:01:35
# 2553            1      1506024042  09/21/2017, 16:00:42
# 2554            1      1506092422  09/22/2017, 11:00:22
#
#                                                 ratings  \
# 0     [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2     [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3     [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4     [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 5     [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...                                                 ...
# 2550  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2551  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2552  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2553  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2554  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 2     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 3     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 4     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 5     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# ...                                                 ...
# 2550  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2551  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2552  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...
# 2553  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 2554  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                         speaker_occupation  \
# 0                          Author/educator
# 2                         Climate advocate
# 3                     Technology columnist
# 4       Activist for environmental justice
# 5     Global health expert; data visionary
# ...                                    ...
# 2550                            Journalist
# 2551                        Astrobiologist
# 2552                     Robotics engineer
# 2553                   Public intellectual
# 2554                         Game designer
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 2     ['alternative energy', 'cars', 'climate change...
# 3     ['computers', 'entertainment', 'interface desi...
# 4     ['MacArthur grant', 'activism', 'business', 'c...
# 5     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...                                                 ...
# 2550  ['TED Residency', 'United States', 'community'...
# 2551  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2552  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2553  ['Internet', 'TEDx', 'United States', 'communi...
# 2554  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 2                           Averting the climate crisis
# 3                                      Simplicity sells
# 4                                   Greening the ghetto
# 5                       The best stats you've ever seen
# ...                                                 ...
# 2550  What we're missing in the debate about immigra...
# 2551                    The most Martian place on Earth
# 2552  What intelligent machines can learn from a sch...
# 2553       A black man goes undercover in the alt-right
# 2554  How a video game might help us build better ci...
#
#                                                     url     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 2     https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 3     https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 4     https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 5     https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# ...                                                 ...       ...
# 2550  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2551  https://www.ted.com/talks/armando_azua_bustos_...    417470
# 2552  https://www.ted.com/talks/radhika_nagpal_what_...    375647
# 2553  https://www.ted.com/talks/theo_e_j_wilson_a_bl...    419309
# 2554  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
# [2550 rows x 19 columns]

# %%
df[df['languages'] == 0]
# Out:
# Empty DataFrame
# Columns: [comments, description, duration, event, film_date, film_date_hr, languages, main_speaker, name, num_speaker, published_date, published_date_hr, ratings, related_talks, speaker_occupation, tags, title, url, views]
# Index: []

# %%
df[(df['num_speaker'] <= 0)]
# Out:
#      comments                                        description  duration  \
# 4         200  In an emotionally charged talk, MacArthur-winn...     18.60
# 7         672  Tony Robbins discusses the "invisible forces" ...     21.75
# 15        242  Jeff Han shows off a cheap, scalable multi-tou...      8.78
# 19         88  Fumes from indoor cooking fires kill more than...     15.10
# 53         85  Robert Neuwirth, author of "Shadow Cities," fi...     14.05
# 156       145  Nokia researcher Jan Chipchase's investigation...     16.05
# 210       156  Neuroscientist and inventor Christopher deChar...      4.03
# 260        59  The wonderful Nellie McKay sings "Mother of Pe...      5.57
# 283       174  Speaking at LIFT 2007, Sugata Mitra talks abou...     20.98
# 284        92  Ory Okolloh tells the story of her life and he...     16.63
#
#               event   film_date          film_date_hr  languages  \
# 4           TED2006  1140912000  02/25/2006, 19:00:00         35
# 7           TED2006  1138838400  02/01/2006, 19:00:00          1
# 15          TED2006  1139184000  02/05/2006, 19:00:00         27
# 19          TED2006  1140739200  02/23/2006, 19:00:00         27
# 53   TEDGlobal 2005  1121299200  07/13/2005, 20:00:00         22
# 156         TED2007  1172880000  03/02/2007, 19:00:00         22
# 210         TED2008  1204243200  02/28/2008, 19:00:00         38
# 260         TED2008  1201910400  02/01/2008, 19:00:00         24
# 283       LIFT 2007  1170374400  02/01/2007, 19:00:00         30
# 284  TEDGlobal 2007  1181088000  06/05/2007, 20:00:00         19
#
#              main_speaker                                               name  \
# 4           Majora Carter                 Majora Carter: Greening the ghetto
# 7            Tony Robbins                 Tony Robbins: Why we do what we do
# 15               Jeff Han  Jeff Han: The radical promise of the multi-tou...
# 19              Amy Smith           Amy Smith: Simple designs to save a life
# 53        Robert Neuwirth  Robert Neuwirth: The hidden world of shadow ci...
# 156         Jan Chipchase   Jan Chipchase: The anthropology of mobile phones
# 210  Christopher deCharms  Christopher deCharms: A look inside the brain ...
# 260          Nellie McKay    Nellie McKay: "Mother of Pearl," "If I Had You"
# 283          Sugata Mitra            Sugata Mitra: Kids can teach themselves
# 284           Ory Okolloh              Ory Okolloh: How I became an activist
#
#      num_speaker  published_date     published_date_hr  \
# 4             -1      1151367060  06/26/2006, 20:11:00
# 7              0      1151440680  06/27/2006, 16:38:00
# 15            -1      1154391060  07/31/2006, 20:11:00
# 19             0      1155600660  08/14/2006, 20:11:00
# 53             0      1167696660  01/01/2007, 19:11:00
# 156           -1      1192716300  10/18/2007, 10:05:00
# 210            0      1206377160  03/24/2008, 12:46:00
# 260            0      1215756000  07/11/2008, 02:00:00
# 283           -1      1219798800  08/26/2008, 21:00:00
# 284           -1      1219885200  08/27/2008, 21:00:00
#
#                                                ratings  \
# 4    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 7    [{'id': 7, 'name': 'Funny', 'count': 1102}, {'...
# 15   [{'id': 9, 'name': 'Ingenious', 'count': 1014}...
# 19   [{'id': 9, 'name': 'Ingenious', 'count': 321},...
# 53   [{'id': 8, 'name': 'Informative', 'count': 265...
# 156  [{'id': 8, 'name': 'Informative', 'count': 454...
# 210  [{'id': 21, 'name': 'Unconvincing', 'count': 8...
# 260  [{'id': 10, 'name': 'Inspiring', 'count': 79},...
# 283  [{'id': 10, 'name': 'Inspiring', 'count': 620}...
# 284  [{'id': 24, 'name': 'Persuasive', 'count': 68}...
#
#                                          related_talks  \
# 4    [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 7    [{'id': 229, 'hero': 'https://pe.tedcdn.com/im...
# 15   [{'id': 685, 'hero': 'https://pe.tedcdn.com/im...
# 19   [{'id': 1561, 'hero': 'https://pe.tedcdn.com/i...
# 53   [{'id': 643, 'hero': 'https://pe.tedcdn.com/im...
# 156  [{'id': 19, 'hero': 'https://pe.tedcdn.com/ima...
# 210  [{'id': 184, 'hero': 'https://pe.tedcdn.com/im...
# 260  [{'id': 287, 'hero': 'https://pe.tedcdn.com/im...
# 283  [{'id': 66, 'hero': 'https://pe.tedcdn.com/ima...
# 284  [{'id': 127, 'hero': 'https://pe.tedcdn.com/im...
#
#                               speaker_occupation  \
# 4             Activist for environmental justice
# 7    Life coach; expert in leadership psychology
# 15             Human-computer interface designer
# 19                            inventor, engineer
# 53                                        Author
# 156                          User anthropologist
# 210                             Brain researcher
# 260                            Singer/songwriter
# 283                         Education researcher
# 284                         Blogger and activist
#
#                                                   tags  \
# 4    ['MacArthur grant', 'activism', 'business', 'c...
# 7    ['business', 'culture', 'entertainment', 'goal...
# 15   ['demo', 'design', 'interface design', 'techno...
# 19   ['MacArthur grant', 'alternative energy', 'des...
# 53   ['business', 'cities', 'culture', 'entrepreneu...
# 156  ['cities', 'communication', 'culture', 'design...
# 210  ['biology', 'brain', 'business', 'demo', 'medi...
# 260  ['entertainment', 'humor', 'live music', 'love...
# 283  ['children', 'cities', 'culture', 'education',...
# 284  ['Africa', 'activism', 'global issues', 'ident...
#
#                                                 title  \
# 4                                 Greening the ghetto
# 7                                Why we do what we do
# 15   The radical promise of the multi-touch interface
# 19                      Simple designs to save a life
# 53                  The hidden world of shadow cities
# 156                 The anthropology of mobile phones
# 210              A look inside the brain in real time
# 260                 "Mother of Pearl," "If I Had You"
# 283                         Kids can teach themselves
# 284                          How I became an activist
#
#                                                    url     views
# 4    https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 7    https://www.ted.com/talks/tony_robbins_asks_wh...  20685401
# 15   https://www.ted.com/talks/jeff_han_demos_his_b...   4531020
# 19   https://www.ted.com/talks/amy_smith_shares_sim...   1415724
# 53   https://www.ted.com/talks/robert_neuwirth_on_o...    673036
# 156  https://www.ted.com/talks/jan_chipchase_on_our...    694378
# 210  https://www.ted.com/talks/christopher_decharms...   1485761
# 260  https://www.ted.com/talks/nellie_mckay_sings_f...   1013879
# 283  https://www.ted.com/talks/sugata_mitra_shows_h...   1486853
# 284  https://www.ted.com/talks/ory_okolloh_on_becom...    321896

# %%
df["num_speaker"].replace(0, 1, inplace=True)
df["num_speaker"].replace(-1, 1, inplace=True)

# %% [markdown]
# Finally, we're able to get back to the first issue of `main_speaker` having blanks. We can use `df['main_speaker'].isna()` to check the rows of `main_speaker` that are empty

# %%
df['main_speaker'].isna()
# Out:
# 0       False
# 2        True
# 3        True
# 4       False
# 5       False
#         ...
# 2550    False
# 2551    False
# 2552    False
# 2553    False
# 2554    False
# Name: main_speaker, Length: 2550, dtype: bool

# %% [markdown]
# If we look at the `description`, `main_speaker` and `name` columns for all of the blank rows, we see some useful information

# %%
df[df['main_speaker'].isna()][["description", "main_speaker","name"]]
# Out:
#                                            description main_speaker  \
# 2    With the same humor and humanity he exuded in ...          NaN
# 3    New York Times columnist David Pogue takes aim...          NaN
# 13   Jehane Noujaim unveils her 2006 TED Prize wish...          NaN
# 34   Cambridge researcher Aubrey de Grey argues tha...          NaN
# 62   Writer and actor Anna Deavere Smith gives life...          NaN
# 75   Graphic designer Stefan Sagmeister takes the a...          NaN
# 93   Green-minded architect and designer William Mc...          NaN
# 123  Alan Russell studies regenerative medicine -- ...          NaN
# 161  Lawrence Lessig, the Net’s most celebrated law...          NaN
# 191  What if human consciousness isn't the end-all ...          NaN
# 222  Novelist Amy Tan digs deep into the creative p...          NaN
# 237  Around the world right now, one billion people...          NaN
# 249  Benjamin Zander has two infectious passions: c...          NaN
# 268  Chris Abani tells stories of people: People st...          NaN
# 282  Imagine hearing great, departed pianists play ...          NaN
# 318  Humorist John Hodgman rambles through a new st...          NaN
# 362  Reporter Jennifer 8. Lee talks about her hunt ...          NaN
# 444  By analyzing raw data on violent incidents in ...          NaN
# 456  "Bonk" author Mary Roach delves into obscure s...          NaN
# 478  Organ virtuoso Qi Zhang plays her electric ren...          NaN
# 539  Advertising adds value to a product by changin...          NaN
# 591  Legendary jazz musician Herbie Hancock deliver...          NaN
# 670  Some 80 to 90 percent of undersea creatures ma...          NaN
# 721  Lego blocks: playtime mainstay for industrious...          NaN
#
#                                                   name
# 2                 Al Gore: Averting the climate crisis
# 3                        David Pogue: Simplicity sells
# 13       Jehane Noujaim: My wish: A global day of film
# 34              Aubrey de Grey: A roadmap to end aging
# 62        Anna Deavere Smith: Four American characters
# 75              Stefan Sagmeister: Happiness by design
# 93          William McDonough: Cradle to cradle design
# 123  Alan Russell: The potential of regenerative me...
# 161        Lawrence Lessig: Laws that choke creativity
# 191                 Michael Pollan: A plant's-eye view
# 222               Amy Tan: Where does creativity hide?
# 237                 Paul Collier: The "bottom billion"
# 249  Benjamin Zander: The transformative power of c...
# 268                           Chris Abani: On humanity
# 282  John Q. Walker: Great piano performances, recr...
# 318      John Hodgman: Aliens, love -- where are they?
# 362          Jennifer 8. Lee: The hunt for General Tso
# 444               Sean Gourley: The mathematics of war
# 456  Mary Roach: 10 things you didn't know about or...
# 478        Qi Zhang: An electrifying organ performance
# 539       Rory Sutherland: Life lessons from an ad man
# 591                    Herbie Hancock: An all-star set
# 670  Edith Widder: Glowing life in an underwater world
# 721               Hillel Cooperman: Legos for grownups

# %% [markdown]
# Without that useful information, we can always just replace empty values with a default value like so:

# %%
df.fillna("unknown", inplace=True)

# %%
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...     19.40
# 2          265  With the same humor and humanity he exuded in ...     16.28
# 3          124  New York Times columnist David Pogue takes aim...     21.43
# 4          200  In an emotionally charged talk, MacArthur-winn...     18.60
# 5          593  You've never seen data presented like this. Wi...     19.83
# ...        ...                                                ...       ...
# 2550        17  Between 2008 and 2016, the United States depor...      7.93
# 2551         6  How can you study Mars without a spaceship? He...      4.83
# 2552        10  Science fiction visions of the future show us ...     10.85
# 2553        32  In an unmissable talk about race and politics ...     18.33
# 2554         8  With more than half of the world population li...      8.65
#
#              event   film_date          film_date_hr  languages  \
# 0          TED2006  1140825600  02/24/2006, 19:00:00         60
# 2          TED2006  1140825600  02/24/2006, 19:00:00         43
# 3          TED2006  1140739200  02/23/2006, 19:00:00         26
# 4          TED2006  1140912000  02/25/2006, 19:00:00         35
# 5          TED2006  1140566400  02/21/2006, 19:00:00         48
# ...            ...         ...                   ...        ...
# 2550       TED2017  1496707200  06/05/2017, 20:00:00          4
# 2551       TED2017  1492992000  04/23/2017, 20:00:00          3
# 2552       TED2017  1492992000  04/23/2017, 20:00:00          1
# 2553  TEDxMileHigh  1499472000  07/07/2017, 20:00:00          1
# 2554       TED2017  1492992000  04/23/2017, 20:00:00          1
#
#              main_speaker                                               name  \
# 0                Emma Rob          Ken Robinson: Do schools kill creativity?
# 2                 unknown               Al Gore: Averting the climate crisis
# 3                 unknown                      David Pogue: Simplicity sells
# 4           Majora Carter                 Majora Carter: Greening the ghetto
# 5            Hans Rosling      Hans Rosling: The best stats you've ever seen
# ...                   ...                                                ...
# 2550     Duarte Geraldino  Duarte Geraldino: What we're missing in the de...
# 2551  Armando Azua-Bustos  Armando Azua-Bustos: The most Martian place on...
# 2552       Radhika Nagpal  Radhika Nagpal: What intelligent machines can ...
# 2553     Theo E.J. Wilson  Theo E.J. Wilson: A black man goes undercover ...
# 2554    Karoliina Korppoo  Karoliina Korppoo: How a video game might help...
#
#       num_speaker  published_date     published_date_hr  \
# 0               1      1151367060  06/26/2006, 20:11:00
# 2               1      1151367060  06/26/2006, 20:11:00
# 3               1      1151367060  06/26/2006, 20:11:00
# 4               1      1151367060  06/26/2006, 20:11:00
# 5               1      1151440680  06/27/2006, 16:38:00
# ...           ...             ...                   ...
# 2550            1      1505851216  09/19/2017, 16:00:16
# 2551            1      1505919737  09/20/2017, 11:02:17
# 2552            1      1506006095  09/21/2017, 11:01:35
# 2553            1      1506024042  09/21/2017, 16:00:42
# 2554            1      1506092422  09/22/2017, 11:00:22
#
#                                                 ratings  \
# 0     [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2     [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3     [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4     [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 5     [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...                                                 ...
# 2550  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2551  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2552  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2553  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2554  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 2     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 3     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 4     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 5     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# ...                                                 ...
# 2550  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2551  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2552  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...
# 2553  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 2554  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                         speaker_occupation  \
# 0                          Author/educator
# 2                         Climate advocate
# 3                     Technology columnist
# 4       Activist for environmental justice
# 5     Global health expert; data visionary
# ...                                    ...
# 2550                            Journalist
# 2551                        Astrobiologist
# 2552                     Robotics engineer
# 2553                   Public intellectual
# 2554                         Game designer
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 2     ['alternative energy', 'cars', 'climate change...
# 3     ['computers', 'entertainment', 'interface desi...
# 4     ['MacArthur grant', 'activism', 'business', 'c...
# 5     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...                                                 ...
# 2550  ['TED Residency', 'United States', 'community'...
# 2551  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2552  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2553  ['Internet', 'TEDx', 'United States', 'communi...
# 2554  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 2                           Averting the climate crisis
# 3                                      Simplicity sells
# 4                                   Greening the ghetto
# 5                       The best stats you've ever seen
# ...                                                 ...
# 2550  What we're missing in the debate about immigra...
# 2551                    The most Martian place on Earth
# 2552  What intelligent machines can learn from a sch...
# 2553       A black man goes undercover in the alt-right
# 2554  How a video game might help us build better ci...
#
#                                                     url     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 2     https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 3     https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 4     https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 5     https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# ...                                                 ...       ...
# 2550  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2551  https://www.ted.com/talks/armando_azua_bustos_...    417470
# 2552  https://www.ted.com/talks/radhika_nagpal_what_...    375647
# 2553  https://www.ted.com/talks/theo_e_j_wilson_a_bl...    419309
# 2554  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
# [2550 rows x 19 columns]

# %%
df[df['main_speaker'] == 'unknown'].shape
# Out:
# (24, 19)

# %% [markdown]
# But here, `name` also contains the speaker's name. So we can rip it and then adjust `main_speaker` and `name` accordingly

# %%
df['name'].head()
# Out:
# 0        Ken Robinson: Do schools kill creativity?
# 2             Al Gore: Averting the climate crisis
# 3                    David Pogue: Simplicity sells
# 4               Majora Carter: Greening the ghetto
# 5    Hans Rosling: The best stats you've ever seen
# Name: name, dtype: object

# %%
df['main_speaker'] = df['name'].str.split(':',1).str[0]

# %%
df['name'] = df['name'].str.split(':',1).str[1]

# %%
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...     19.40
# 2          265  With the same humor and humanity he exuded in ...     16.28
# 3          124  New York Times columnist David Pogue takes aim...     21.43
# 4          200  In an emotionally charged talk, MacArthur-winn...     18.60
# 5          593  You've never seen data presented like this. Wi...     19.83
# ...        ...                                                ...       ...
# 2550        17  Between 2008 and 2016, the United States depor...      7.93
# 2551         6  How can you study Mars without a spaceship? He...      4.83
# 2552        10  Science fiction visions of the future show us ...     10.85
# 2553        32  In an unmissable talk about race and politics ...     18.33
# 2554         8  With more than half of the world population li...      8.65
#
#              event   film_date          film_date_hr  languages  \
# 0          TED2006  1140825600  02/24/2006, 19:00:00         60
# 2          TED2006  1140825600  02/24/2006, 19:00:00         43
# 3          TED2006  1140739200  02/23/2006, 19:00:00         26
# 4          TED2006  1140912000  02/25/2006, 19:00:00         35
# 5          TED2006  1140566400  02/21/2006, 19:00:00         48
# ...            ...         ...                   ...        ...
# 2550       TED2017  1496707200  06/05/2017, 20:00:00          4
# 2551       TED2017  1492992000  04/23/2017, 20:00:00          3
# 2552       TED2017  1492992000  04/23/2017, 20:00:00          1
# 2553  TEDxMileHigh  1499472000  07/07/2017, 20:00:00          1
# 2554       TED2017  1492992000  04/23/2017, 20:00:00          1
#
#              main_speaker                                               name  \
# 0            Ken Robinson                        Do schools kill creativity?
# 2                 Al Gore                        Averting the climate crisis
# 3             David Pogue                                   Simplicity sells
# 4           Majora Carter                                Greening the ghetto
# 5            Hans Rosling                    The best stats you've ever seen
# ...                   ...                                                ...
# 2550     Duarte Geraldino   What we're missing in the debate about immigr...
# 2551  Armando Azua-Bustos                    The most Martian place on Earth
# 2552       Radhika Nagpal   What intelligent machines can learn from a sc...
# 2553     Theo E.J. Wilson       A black man goes undercover in the alt-right
# 2554    Karoliina Korppoo   How a video game might help us build better c...
#
#       num_speaker  published_date     published_date_hr  \
# 0               1      1151367060  06/26/2006, 20:11:00
# 2               1      1151367060  06/26/2006, 20:11:00
# 3               1      1151367060  06/26/2006, 20:11:00
# 4               1      1151367060  06/26/2006, 20:11:00
# 5               1      1151440680  06/27/2006, 16:38:00
# ...           ...             ...                   ...
# 2550            1      1505851216  09/19/2017, 16:00:16
# 2551            1      1505919737  09/20/2017, 11:02:17
# 2552            1      1506006095  09/21/2017, 11:01:35
# 2553            1      1506024042  09/21/2017, 16:00:42
# 2554            1      1506092422  09/22/2017, 11:00:22
#
#                                                 ratings  \
# 0     [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2     [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3     [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4     [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 5     [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...                                                 ...
# 2550  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2551  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2552  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2553  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2554  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 2     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 3     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 4     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 5     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# ...                                                 ...
# 2550  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2551  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2552  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...
# 2553  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 2554  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                         speaker_occupation  \
# 0                          Author/educator
# 2                         Climate advocate
# 3                     Technology columnist
# 4       Activist for environmental justice
# 5     Global health expert; data visionary
# ...                                    ...
# 2550                            Journalist
# 2551                        Astrobiologist
# 2552                     Robotics engineer
# 2553                   Public intellectual
# 2554                         Game designer
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 2     ['alternative energy', 'cars', 'climate change...
# 3     ['computers', 'entertainment', 'interface desi...
# 4     ['MacArthur grant', 'activism', 'business', 'c...
# 5     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...                                                 ...
# 2550  ['TED Residency', 'United States', 'community'...
# 2551  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2552  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2553  ['Internet', 'TEDx', 'United States', 'communi...
# 2554  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 2                           Averting the climate crisis
# 3                                      Simplicity sells
# 4                                   Greening the ghetto
# 5                       The best stats you've ever seen
# ...                                                 ...
# 2550  What we're missing in the debate about immigra...
# 2551                    The most Martian place on Earth
# 2552  What intelligent machines can learn from a sch...
# 2553       A black man goes undercover in the alt-right
# 2554  How a video game might help us build better ci...
#
#                                                     url     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 2     https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 3     https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 4     https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 5     https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# ...                                                 ...       ...
# 2550  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2551  https://www.ted.com/talks/armando_azua_bustos_...    417470
# 2552  https://www.ted.com/talks/radhika_nagpal_what_...    375647
# 2553  https://www.ted.com/talks/theo_e_j_wilson_a_bl...    419309
# 2554  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
# [2550 rows x 19 columns]

# %%
df['name'][0]
# Out:
# ' Do schools kill creativity?'

# %%
df["title"][0]
# Out:
# 'Do schools kill creativity?'

# %%
df['name'] = df['name'].str[1:]

# %%
df[~(df['name'] == df['title'])]
# Out:
#       comments                                        description  duration  \
# 1548       130  Apes, dolphins and elephants are animals with ...     20.02
# 1554       153  Once it's created, plastic (almost) never dies...      9.33
# 1724       208  We live in a world of unseeable beauty, so sub...      7.40
# 1750        44  Do our smells make us sexy? Popular science su...     14.88
# 1774       397  Here's a talk that could literally change your...     14.68
# 1850        62  Does a set of data make you feel more comforta...     12.38
# 2074       217  Geneticist Jennifer Doudna co-invented a groun...     15.88
# 2471        20  When Michael Bierut was tapped to design a log...     12.43
# 2517        14  It's been a weird 100 years for artists and cr...     10.52
#
#                  event   film_date          film_date_hr  languages  \
# 1548           TED2013  1362009600  02/27/2013, 19:00:00         20
# 1554           TED2013  1362009600  02/27/2013, 19:00:00         32
# 1724           TED2014  1395187200  03/18/2014, 20:00:00         38
# 1750   TEDxLeuvenSalon  1379376000  09/16/2013, 20:00:00         26
# 1774   TEDSalon NY2014  1400112000  05/14/2014, 20:00:00         33
# 1850           TED@IBM  1411603200  09/24/2014, 20:00:00         25
# 2074  TEDGlobal>London  1443484800  09/28/2015, 20:00:00         29
# 2471            TEDNYC  1488931200  03/07/2017, 19:00:00         16
# 2517           TED2017  1492992000  04/23/2017, 20:00:00          6
#
#                                            main_speaker  \
# 1548     The interspecies internet? An idea in progress
# 1554  Two young scientists break down plastics with ...
# 1724                                 Louie Schwartzberg
# 1750                                     Tristram Wyatt
# 1774                                         Ruth Chang
# 1850                                     Susan Etlinger
# 2074                                    Jennifer Doudna
# 2471                                     Michael Bierut
# 2517                                         Jack Conte
#
#                                                    name  num_speaker  \
# 1548                                                NaN            4
# 1554                                                NaN            1
# 1724               Hidden miracles of the natural world            1
# 1750          The smelly mystery of the human pheromone            1
# 1774                           How to make hard choices            1
# 1850              What do we do with all this big data?            1
# 2074                    How CRISPR lets us edit our DNA            1
# 2471  How to design a library that makes kids want t...            1
# 2517  How artists can (finally) get paid in the digi...            1
#
#       published_date     published_date_hr  \
# 1548      1373468405  07/10/2013, 11:00:05
# 1554      1374160566  07/18/2013, 11:16:06
# 1724      1397055205  04/09/2014, 10:53:25
# 1750      1400166002  05/15/2014, 11:00:02
# 1774      1403103639  06/18/2014, 11:00:39
# 1850      1413816332  10/20/2014, 10:45:32
# 2074      1445353411  10/20/2015, 11:03:31
# 2471      1496418030  06/02/2017, 11:40:30
# 2517      1502895617  08/16/2017, 11:00:17
#
#                                                 ratings  \
# 1548  [{'id': 23, 'name': 'Jaw-dropping', 'count': 5...
# 1554  [{'id': 9, 'name': 'Ingenious', 'count': 174},...
# 1724  [{'id': 1, 'name': 'Beautiful', 'count': 2341}...
# 1750  [{'id': 8, 'name': 'Informative', 'count': 496...
# 1774  [{'id': 8, 'name': 'Informative', 'count': 172...
# 1850  [{'id': 8, 'name': 'Informative', 'count': 290...
# 2074  [{'id': 24, 'name': 'Persuasive', 'count': 145...
# 2471  [{'id': 7, 'name': 'Funny', 'count': 111}, {'i...
# 2517  [{'id': 1, 'name': 'Beautiful', 'count': 31}, ...
#
#                                           related_talks  \
# 1548  [{'id': 1758, 'hero': 'https://pe.tedcdn.com/i...
# 1554  [{'id': 1239, 'hero': 'https://pe.tedcdn.com/i...
# 1724  [{'id': 1283, 'hero': 'https://pe.tedcdn.com/i...
# 1750  [{'id': 393, 'hero': 'https://pe.tedcdn.com/im...
# 1774  [{'id': 93, 'hero': 'https://pe.tedcdn.com/ima...
# 1850  [{'id': 1152, 'hero': 'https://pe.tedcdn.com/i...
# 2074  [{'id': 35, 'hero': 'https://pe.tedcdn.com/ima...
# 2471  [{'id': 418, 'hero': 'https://pe.tedcdn.com/im...
# 2517  [{'id': 1653, 'hero': 'https://pe.tedcdn.com/i...
#
#           speaker_occupation  \
# 1548  Cognitive psychologist
# 1554    Science fair winners
# 1724               Filmmaker
# 1750               Zoologist
# 1774             Philosopher
# 1850            Data analyst
# 2074               Biologist
# 2471        Designer, critic
# 2517  Musician, entrepreneur
#
#                                                    tags  \
# 1548              ['Internet', 'animals', 'technology']
# 1554  ['bacteria', 'biology', 'ecology', 'environmen...
# 1724  ['bacteria', 'film', 'insects', 'nanoscale', '...
# 1750            ['TEDx', 'animals', 'biology', 'smell']
# 1774        ['choice', 'decision-making', 'philosophy']
# 1850                                           ['data']
# 2074  ['Bioethics', 'CRISPR', 'DNA', 'biotech', 'eng...
# 2471       ['TEDNYC', 'design', 'education', 'library']
# 2517  ['art', 'business', 'creativity', 'entrepreneu...
#
#                                                   title  \
# 1548     The interspecies internet? An idea in progress
# 1554  Two young scientists break down plastics with ...
# 1724               Hidden miracles of the natural world
# 1750       The smelly mystery of the human pheromone
# 1774                          How to make hard choices
# 1850             What do we do with all this big data?
# 2074                    How CRISPR lets us edit our DNA
# 2471  How to design a library that makes kids want t...
# 2517  How artists can (finally) get paid in the digi...
#
#                                                     url    views
# 1548  https://www.ted.com/talks/the_interspecies_int...   717979
# 1554  https://www.ted.com/talks/two_young_scientists...  1212774
# 1724  https://www.ted.com/talks/louie_schwartzberg_h...  7015800
# 1750  https://www.ted.com/talks/tristram_wyatt_the_s...  1189824
# 1774  https://www.ted.com/talks/ruth_chang_how_to_ma...  4933802
# 1850  https://www.ted.com/talks/susan_etlinger_what_...  1209472
# 2074  https://www.ted.com/talks/jennifer_doudna_we_c...  1936760
# 2471  https://www.ted.com/talks/michael_bierut_how_t...  1323235
# 2517  https://www.ted.com/talks/jack_conte_how_artis...   734095

# %%
df[df['name'].isna()]['main_speaker']
# Out:
# 1548       The interspecies internet? An idea in progress
# 1554    Two young scientists break down plastics with ...
# Name: main_speaker, dtype: object

# %%
df.loc[1548]['main_speaker'] = "unknown"
df.loc[1554]['main_speaker'] = "unknown"
# Out:
# <ipython-input-43-42b7b4c38d32>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[1548]['main_speaker'] = "unknown"
# <ipython-input-43-42b7b4c38d32>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[1554]['main_speaker'] = "unknown"

# %%
df.drop('name', axis=1, inplace=True)

# %%
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...     19.40
# 2          265  With the same humor and humanity he exuded in ...     16.28
# 3          124  New York Times columnist David Pogue takes aim...     21.43
# 4          200  In an emotionally charged talk, MacArthur-winn...     18.60
# 5          593  You've never seen data presented like this. Wi...     19.83
# ...        ...                                                ...       ...
# 2550        17  Between 2008 and 2016, the United States depor...      7.93
# 2551         6  How can you study Mars without a spaceship? He...      4.83
# 2552        10  Science fiction visions of the future show us ...     10.85
# 2553        32  In an unmissable talk about race and politics ...     18.33
# 2554         8  With more than half of the world population li...      8.65
#
#              event   film_date          film_date_hr  languages  \
# 0          TED2006  1140825600  02/24/2006, 19:00:00         60
# 2          TED2006  1140825600  02/24/2006, 19:00:00         43
# 3          TED2006  1140739200  02/23/2006, 19:00:00         26
# 4          TED2006  1140912000  02/25/2006, 19:00:00         35
# 5          TED2006  1140566400  02/21/2006, 19:00:00         48
# ...            ...         ...                   ...        ...
# 2550       TED2017  1496707200  06/05/2017, 20:00:00          4
# 2551       TED2017  1492992000  04/23/2017, 20:00:00          3
# 2552       TED2017  1492992000  04/23/2017, 20:00:00          1
# 2553  TEDxMileHigh  1499472000  07/07/2017, 20:00:00          1
# 2554       TED2017  1492992000  04/23/2017, 20:00:00          1
#
#              main_speaker  num_speaker  published_date     published_date_hr  \
# 0            Ken Robinson            1      1151367060  06/26/2006, 20:11:00
# 2                 Al Gore            1      1151367060  06/26/2006, 20:11:00
# 3             David Pogue            1      1151367060  06/26/2006, 20:11:00
# 4           Majora Carter            1      1151367060  06/26/2006, 20:11:00
# 5            Hans Rosling            1      1151440680  06/27/2006, 16:38:00
# ...                   ...          ...             ...                   ...
# 2550     Duarte Geraldino            1      1505851216  09/19/2017, 16:00:16
# 2551  Armando Azua-Bustos            1      1505919737  09/20/2017, 11:02:17
# 2552       Radhika Nagpal            1      1506006095  09/21/2017, 11:01:35
# 2553     Theo E.J. Wilson            1      1506024042  09/21/2017, 16:00:42
# 2554    Karoliina Korppoo            1      1506092422  09/22/2017, 11:00:22
#
#                                                 ratings  \
# 0     [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2     [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3     [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4     [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 5     [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...                                                 ...
# 2550  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2551  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2552  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2553  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2554  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 2     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 3     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 4     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 5     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# ...                                                 ...
# 2550  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2551  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2552  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...
# 2553  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 2554  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                         speaker_occupation  \
# 0                          Author/educator
# 2                         Climate advocate
# 3                     Technology columnist
# 4       Activist for environmental justice
# 5     Global health expert; data visionary
# ...                                    ...
# 2550                            Journalist
# 2551                        Astrobiologist
# 2552                     Robotics engineer
# 2553                   Public intellectual
# 2554                         Game designer
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 2     ['alternative energy', 'cars', 'climate change...
# 3     ['computers', 'entertainment', 'interface desi...
# 4     ['MacArthur grant', 'activism', 'business', 'c...
# 5     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...                                                 ...
# 2550  ['TED Residency', 'United States', 'community'...
# 2551  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2552  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2553  ['Internet', 'TEDx', 'United States', 'communi...
# 2554  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 2                           Averting the climate crisis
# 3                                      Simplicity sells
# 4                                   Greening the ghetto
# 5                       The best stats you've ever seen
# ...                                                 ...
# 2550  What we're missing in the debate about immigra...
# 2551                    The most Martian place on Earth
# 2552  What intelligent machines can learn from a sch...
# 2553       A black man goes undercover in the alt-right
# 2554  How a video game might help us build better ci...
#
#                                                     url     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 2     https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 3     https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 4     https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 5     https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# ...                                                 ...       ...
# 2550  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2551  https://www.ted.com/talks/armando_azua_bustos_...    417470
# 2552  https://www.ted.com/talks/radhika_nagpal_what_...    375647
# 2553  https://www.ted.com/talks/theo_e_j_wilson_a_bl...    419309
# 2554  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
# [2550 rows x 18 columns]

# %%
df.columns.tolist()
# Out:
# ['comments',
#  'description',
#  'duration',
#  'event',
#  'film_date',
#  'film_date_hr',
#  'languages',
#  'main_speaker',
#  'num_speaker',
#  'published_date',
#  'published_date_hr',
#  'ratings',
#  'related_talks',
#  'speaker_occupation',
#  'tags',
#  'title',
#  'url',
#  'views']

# %%
df = df.reindex([
'title',
 'description',
 'main_speaker',
 'speaker_occupation',
 'num_speaker',
 'languages',
 'duration',
 'event',
 'tags',
 'ratings',
 'related_talks',
 'film_date',
 'film_date_hr',
 'published_date',
 'published_date_hr',
 'url',
 'comments',
 'views' 
], axis=1)

# %%
df
# Out:
#                                                   title  \
# 0                           Do schools kill creativity?
# 2                           Averting the climate crisis
# 3                                      Simplicity sells
# 4                                   Greening the ghetto
# 5                       The best stats you've ever seen
# ...                                                 ...
# 2550  What we're missing in the debate about immigra...
# 2551                    The most Martian place on Earth
# 2552  What intelligent machines can learn from a sch...
# 2553       A black man goes undercover in the alt-right
# 2554  How a video game might help us build better ci...
#
#                                             description         main_speaker  \
# 0     Sir Ken Robinson makes an entertaining and pro...         Ken Robinson
# 2     With the same humor and humanity he exuded in ...              Al Gore
# 3     New York Times columnist David Pogue takes aim...          David Pogue
# 4     In an emotionally charged talk, MacArthur-winn...        Majora Carter
# 5     You've never seen data presented like this. Wi...         Hans Rosling
# ...                                                 ...                  ...
# 2550  Between 2008 and 2016, the United States depor...     Duarte Geraldino
# 2551  How can you study Mars without a spaceship? He...  Armando Azua-Bustos
# 2552  Science fiction visions of the future show us ...       Radhika Nagpal
# 2553  In an unmissable talk about race and politics ...     Theo E.J. Wilson
# 2554  With more than half of the world population li...    Karoliina Korppoo
#
#                         speaker_occupation  num_speaker  languages  duration  \
# 0                          Author/educator            1         60     19.40
# 2                         Climate advocate            1         43     16.28
# 3                     Technology columnist            1         26     21.43
# 4       Activist for environmental justice            1         35     18.60
# 5     Global health expert; data visionary            1         48     19.83
# ...                                    ...          ...        ...       ...
# 2550                            Journalist            1          4      7.93
# 2551                        Astrobiologist            1          3      4.83
# 2552                     Robotics engineer            1          1     10.85
# 2553                   Public intellectual            1          1     18.33
# 2554                         Game designer            1          1      8.65
#
#              event                                               tags  \
# 0          TED2006  ['children', 'creativity', 'culture', 'dance',...
# 2          TED2006  ['alternative energy', 'cars', 'climate change...
# 3          TED2006  ['computers', 'entertainment', 'interface desi...
# 4          TED2006  ['MacArthur grant', 'activism', 'business', 'c...
# 5          TED2006  ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...            ...                                                ...
# 2550       TED2017  ['TED Residency', 'United States', 'community'...
# 2551       TED2017  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2552       TED2017  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2553  TEDxMileHigh  ['Internet', 'TEDx', 'United States', 'communi...
# 2554       TED2017  ['cities', 'design', 'future', 'infrastructure...
#
#                                                 ratings  \
# 0     [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2     [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3     [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4     [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 5     [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...                                                 ...
# 2550  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2551  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2552  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2553  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2554  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks   film_date  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...  1140825600
# 2     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...  1140825600
# 3     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...  1140739200
# 4     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...  1140912000
# 5     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...  1140566400
# ...                                                 ...         ...
# 2550  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...  1496707200
# 2551  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...  1492992000
# 2552  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...  1492992000
# 2553  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...  1499472000
# 2554  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...  1492992000
#
#               film_date_hr  published_date     published_date_hr  \
# 0     02/24/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 2     02/24/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 3     02/23/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 4     02/25/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 5     02/21/2006, 19:00:00      1151440680  06/27/2006, 16:38:00
# ...                    ...             ...                   ...
# 2550  06/05/2017, 20:00:00      1505851216  09/19/2017, 16:00:16
# 2551  04/23/2017, 20:00:00      1505919737  09/20/2017, 11:02:17
# 2552  04/23/2017, 20:00:00      1506006095  09/21/2017, 11:01:35
# 2553  07/07/2017, 20:00:00      1506024042  09/21/2017, 16:00:42
# 2554  04/23/2017, 20:00:00      1506092422  09/22/2017, 11:00:22
#
#                                                     url  comments     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...      4553  47227110
# 2     https://www.ted.com/talks/al_gore_on_averting_...       265   3200520
# 3     https://www.ted.com/talks/david_pogue_says_sim...       124   1636292
# 4     https://www.ted.com/talks/majora_carter_s_tale...       200   1697550
# 5     https://www.ted.com/talks/hans_rosling_shows_t...       593  12005869
# ...                                                 ...       ...       ...
# 2550  https://www.ted.com/talks/duarte_geraldino_wha...        17    450430
# 2551  https://www.ted.com/talks/armando_azua_bustos_...         6    417470
# 2552  https://www.ted.com/talks/radhika_nagpal_what_...        10    375647
# 2553  https://www.ted.com/talks/theo_e_j_wilson_a_bl...        32    419309
# 2554  https://www.ted.com/talks/karoliina_korppoo_ho...         8    391721
#
# [2550 rows x 18 columns]

# %%
s = df['ratings'][0]
s
# Out:
# "[{'id': 7, 'name': 'Funny', 'count': 19645}, {'id': 1, 'name': 'Beautiful', 'count': 4573}, {'id': 9, 'name': 'Ingenious', 'count': 6073}, {'id': 3, 'name': 'Courageous', 'count': 3253}, {'id': 11, 'name': 'Longwinded', 'count': 387}, {'id': 2, 'name': 'Confusing', 'count': 242}, {'id': 8, 'name': 'Informative', 'count': 7346}, {'id': 22, 'name': 'Fascinating', 'count': 10581}, {'id': 21, 'name': 'Unconvincing', 'count': 300}, {'id': 24, 'name': 'Persuasive', 'count': 10704}, {'id': 23, 'name': 'Jaw-dropping', 'count': 4439}, {'id': 25, 'name': 'OK', 'count': 1174}, {'id': 26, 'name': 'Obnoxious', 'count': 209}, {'id': 10, 'name': 'Inspiring', 'count': 24924}]"

# %%
f = eval(s)
f
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %%
d = {}
for i in f:
    d[i['name']] = {'id': i['id'], 'count': i['count']}

# %%
d['Funny']['count']
# Out:
# 19645

# %%
def convert_ratings(rating):
    d = {}
    for i in eval(rating):
        d[i['name'].lower()] = {'id': i['id'], 'count': i['count']}
    return d

# %%
convert_ratings(df['ratings'][30])
# Out:
# {'funny': {'id': 7, 'count': 1668},
#  'ingenious': {'id': 9, 'count': 1127},
#  'beautiful': {'id': 1, 'count': 333},
#  'longwinded': {'id': 11, 'count': 190},
#  'confusing': {'id': 2, 'count': 80},
#  'courageous': {'id': 3, 'count': 87},
#  'unconvincing': {'id': 21, 'count': 115},
#  'informative': {'id': 8, 'count': 2004},
#  'inspiring': {'id': 10, 'count': 1276},
#  'fascinating': {'id': 22, 'count': 2082},
#  'persuasive': {'id': 24, 'count': 1014},
#  'jaw-dropping': {'id': 23, 'count': 290},
#  'ok': {'id': 25, 'count': 361},
#  'obnoxious': {'id': 26, 'count': 51}}

# %%
df['ratings'].apply(convert_ratings)
# Out:
# 0       {'funny': {'id': 7, 'count': 19645}, 'beautifu...
# 2       {'funny': {'id': 7, 'count': 544}, 'courageous...
# 3       {'funny': {'id': 7, 'count': 964}, 'courageous...
# 4       {'courageous': {'id': 3, 'count': 760}, 'beaut...
# 5       {'ingenious': {'id': 9, 'count': 3202}, 'funny...
#                               ...
# 2550    {'courageous': {'id': 3, 'count': 24}, 'inform...
# 2551    {'fascinating': {'id': 22, 'count': 32}, 'info...
# 2552    {'beautiful': {'id': 1, 'count': 14}, 'informa...
# 2553    {'longwinded': {'id': 11, 'count': 3}, 'unconv...
# 2554    {'unconvincing': {'id': 21, 'count': 21}, 'inf...
# Name: ratings, Length: 2550, dtype: object

# %%
df
# Out:
#                                                   title  \
# 0                           Do schools kill creativity?
# 2                           Averting the climate crisis
# 3                                      Simplicity sells
# 4                                   Greening the ghetto
# 5                       The best stats you've ever seen
# ...                                                 ...
# 2550  What we're missing in the debate about immigra...
# 2551                    The most Martian place on Earth
# 2552  What intelligent machines can learn from a sch...
# 2553       A black man goes undercover in the alt-right
# 2554  How a video game might help us build better ci...
#
#                                             description         main_speaker  \
# 0     Sir Ken Robinson makes an entertaining and pro...         Ken Robinson
# 2     With the same humor and humanity he exuded in ...              Al Gore
# 3     New York Times columnist David Pogue takes aim...          David Pogue
# 4     In an emotionally charged talk, MacArthur-winn...        Majora Carter
# 5     You've never seen data presented like this. Wi...         Hans Rosling
# ...                                                 ...                  ...
# 2550  Between 2008 and 2016, the United States depor...     Duarte Geraldino
# 2551  How can you study Mars without a spaceship? He...  Armando Azua-Bustos
# 2552  Science fiction visions of the future show us ...       Radhika Nagpal
# 2553  In an unmissable talk about race and politics ...     Theo E.J. Wilson
# 2554  With more than half of the world population li...    Karoliina Korppoo
#
#                         speaker_occupation  num_speaker  languages  duration  \
# 0                          Author/educator            1         60     19.40
# 2                         Climate advocate            1         43     16.28
# 3                     Technology columnist            1         26     21.43
# 4       Activist for environmental justice            1         35     18.60
# 5     Global health expert; data visionary            1         48     19.83
# ...                                    ...          ...        ...       ...
# 2550                            Journalist            1          4      7.93
# 2551                        Astrobiologist            1          3      4.83
# 2552                     Robotics engineer            1          1     10.85
# 2553                   Public intellectual            1          1     18.33
# 2554                         Game designer            1          1      8.65
#
#              event                                               tags  \
# 0          TED2006  ['children', 'creativity', 'culture', 'dance',...
# 2          TED2006  ['alternative energy', 'cars', 'climate change...
# 3          TED2006  ['computers', 'entertainment', 'interface desi...
# 4          TED2006  ['MacArthur grant', 'activism', 'business', 'c...
# 5          TED2006  ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...            ...                                                ...
# 2550       TED2017  ['TED Residency', 'United States', 'community'...
# 2551       TED2017  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2552       TED2017  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2553  TEDxMileHigh  ['Internet', 'TEDx', 'United States', 'communi...
# 2554       TED2017  ['cities', 'design', 'future', 'infrastructure...
#
#                                                 ratings  \
# 0     [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 2     [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 3     [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 4     [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 5     [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...                                                 ...
# 2550  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2551  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2552  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2553  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2554  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks   film_date  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...  1140825600
# 2     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...  1140825600
# 3     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...  1140739200
# 4     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...  1140912000
# 5     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...  1140566400
# ...                                                 ...         ...
# 2550  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...  1496707200
# 2551  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...  1492992000
# 2552  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...  1492992000
# 2553  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...  1499472000
# 2554  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...  1492992000
#
#               film_date_hr  published_date     published_date_hr  \
# 0     02/24/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 2     02/24/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 3     02/23/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 4     02/25/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 5     02/21/2006, 19:00:00      1151440680  06/27/2006, 16:38:00
# ...                    ...             ...                   ...
# 2550  06/05/2017, 20:00:00      1505851216  09/19/2017, 16:00:16
# 2551  04/23/2017, 20:00:00      1505919737  09/20/2017, 11:02:17
# 2552  04/23/2017, 20:00:00      1506006095  09/21/2017, 11:01:35
# 2553  07/07/2017, 20:00:00      1506024042  09/21/2017, 16:00:42
# 2554  04/23/2017, 20:00:00      1506092422  09/22/2017, 11:00:22
#
#                                                     url  comments     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...      4553  47227110
# 2     https://www.ted.com/talks/al_gore_on_averting_...       265   3200520
# 3     https://www.ted.com/talks/david_pogue_says_sim...       124   1636292
# 4     https://www.ted.com/talks/majora_carter_s_tale...       200   1697550
# 5     https://www.ted.com/talks/hans_rosling_shows_t...       593  12005869
# ...                                                 ...       ...       ...
# 2550  https://www.ted.com/talks/duarte_geraldino_wha...        17    450430
# 2551  https://www.ted.com/talks/armando_azua_bustos_...         6    417470
# 2552  https://www.ted.com/talks/radhika_nagpal_what_...        10    375647
# 2553  https://www.ted.com/talks/theo_e_j_wilson_a_bl...        32    419309
# 2554  https://www.ted.com/talks/karoliina_korppoo_ho...         8    391721
#
# [2550 rows x 18 columns]

# %%
eval(df['related_talks'][0])
# Out:
# [{'id': 865,
#   'hero': 'https://pe.tedcdn.com/images/ted/172559_800x600.jpg',
#   'speaker': 'Ken Robinson',
#   'title': 'Bring on the learning revolution!',
#   'duration': 1008,
#   'slug': 'sir_ken_robinson_bring_on_the_revolution',
#   'viewed_count': 7266103},
#  {'id': 1738,
#   'hero': 'https://pe.tedcdn.com/images/ted/de98b161ad1434910ff4b56c89de71af04b8b873_1600x1200.jpg',
#   'speaker': 'Ken Robinson',
#   'title': "How to escape education's death valley",
#   'duration': 1151,
#   'slug': 'ken_robinson_how_to_escape_education_s_death_valley',
#   'viewed_count': 6657572},
#  {'id': 2276,
#   'hero': 'https://pe.tedcdn.com/images/ted/3821f3728e0b755c7b9aea2e69cc093eca41abe1_2880x1620.jpg',
#   'speaker': 'Linda Cliatt-Wayman',
#   'title': 'How to fix a broken school? Lead fearlessly, love hard',
#   'duration': 1027,
#   'slug': 'linda_cliatt_wayman_how_to_fix_a_broken_school_lead_fearlessly_love_hard',
#   'viewed_count': 1617101},
#  {'id': 892,
#   'hero': 'https://pe.tedcdn.com/images/ted/e79958940573cc610ccb583619a54866c41ef303_2880x1620.jpg',
#   'speaker': 'Charles Leadbeater',
#   'title': 'Education innovation in the slums',
#   'duration': 1138,
#   'slug': 'charles_leadbeater_on_education',
#   'viewed_count': 772296},
#  {'id': 1232,
#   'hero': 'https://pe.tedcdn.com/images/ted/0e3e4e92d5ee8ae0e43962d447d3f790b31099b8_800x600.jpg',
#   'speaker': 'Geoff Mulgan',
#   'title': 'A short intro to the Studio School',
#   'duration': 376,
#   'slug': 'geoff_mulgan_a_short_intro_to_the_studio_school',
#   'viewed_count': 667971},
#  {'id': 2616,
#   'hero': 'https://pe.tedcdn.com/images/ted/71cde5a6fa6c717488fb55eff9eef939a9241761_2880x1620.jpg',
#   'speaker': 'Kandice Sumner',
#   'title': "How America's public schools keep kids in poverty",
#   'duration': 830,
#   'slug': 'kandice_sumner_how_america_s_public_schools_keep_kids_in_poverty',
#   'viewed_count': 1181333}]

# %%
df[df['title'] == "Bring on the learning revolution!"]
# Out:
#                                  title  \
# 696  Bring on the learning revolution!
#
#                                            description  main_speaker  \
# 696  In this poignant, funny follow-up to his fable...  Ken Robinson
#
#     speaker_occupation  num_speaker  languages  duration    event  \
# 696    Author/educator            1         57      16.8  TED2010
#
#                                                   tags  \
# 696  ['TED Brain Trust', 'children', 'creativity', ...
#
#                                                ratings  \
# 696  [{'id': 7, 'name': 'Funny', 'count': 3000}, {'...
#
#                                          related_talks   film_date  \
# 696  [{'id': 66, 'hero': 'https://pe.tedcdn.com/ima...  1265414400
#
#              film_date_hr  published_date     published_date_hr  \
# 696  02/05/2010, 19:00:00      1274691960  05/24/2010, 05:06:00
#
#                                                    url  comments    views
# 696  https://www.ted.com/talks/sir_ken_robinson_bri...      1234  7266316

# %%
def convert_related(related):
    return [i['title'] for i in eval(related)]

# %%
convert_related(df['related_talks'][23])
# Out:
# ['The  4 a.m. mystery',
#  'My web playroom',
#  'Are you human?',
#  'How to find a wonderful idea',
#  'Visualizing ourselves ... with crowd-sourced data',
#  'How artists can (finally) get paid in the digital age ']

# %%
df[df['title'] == 'Are you human?']
# Out:
#                title                                        description  \
# 1796  Are you human?  Have you ever wondered: Am I a human being? Ze...
#
#      main_speaker    speaker_occupation  num_speaker  languages  duration  \
# 1796     Ze Frank  Humorist, web artist            1         44      4.57
#
#         event                                               tags  \
# 1796  TED2014  ['comedy', 'community', 'entertainment', 'huma...
#
#                                                 ratings  \
# 1796  [{'id': 7, 'name': 'Funny', 'count': 1812}, {'...
#
#                                           related_talks   film_date  \
# 1796  [{'id': 981, 'hero': 'https://pe.tedcdn.com/im...  1395273600
#
#               film_date_hr  published_date     published_date_hr  \
# 1796  03/19/2014, 20:00:00      1405696133  07/18/2014, 11:08:53
#
#                                                     url  comments    views
# 1796  https://www.ted.com/talks/ze_frank_are_you_hum...       251  4058219

# %%
df['related_talks'] = df['related_talks'].apply(convert_related)

# %%
df['ratings'] = df['ratings'].apply(convert_ratings)

# %%
df['ratings'][34].keys()
# Out:
# dict_keys(['unconvincing', 'funny', 'courageous', 'longwinded', 'confusing', 'ingenious', 'beautiful', 'informative', 'inspiring', 'fascinating', 'persuasive', 'ok', 'jaw-dropping', 'obnoxious'])

# %%
df
# Out:
#                                                   title  \
# 0                           Do schools kill creativity?
# 2                           Averting the climate crisis
# 3                                      Simplicity sells
# 4                                   Greening the ghetto
# 5                       The best stats you've ever seen
# ...                                                 ...
# 2550  What we're missing in the debate about immigra...
# 2551                    The most Martian place on Earth
# 2552  What intelligent machines can learn from a sch...
# 2553       A black man goes undercover in the alt-right
# 2554  How a video game might help us build better ci...
#
#                                             description         main_speaker  \
# 0     Sir Ken Robinson makes an entertaining and pro...         Ken Robinson
# 2     With the same humor and humanity he exuded in ...              Al Gore
# 3     New York Times columnist David Pogue takes aim...          David Pogue
# 4     In an emotionally charged talk, MacArthur-winn...        Majora Carter
# 5     You've never seen data presented like this. Wi...         Hans Rosling
# ...                                                 ...                  ...
# 2550  Between 2008 and 2016, the United States depor...     Duarte Geraldino
# 2551  How can you study Mars without a spaceship? He...  Armando Azua-Bustos
# 2552  Science fiction visions of the future show us ...       Radhika Nagpal
# 2553  In an unmissable talk about race and politics ...     Theo E.J. Wilson
# 2554  With more than half of the world population li...    Karoliina Korppoo
#
#                         speaker_occupation  num_speaker  languages  duration  \
# 0                          Author/educator            1         60     19.40
# 2                         Climate advocate            1         43     16.28
# 3                     Technology columnist            1         26     21.43
# 4       Activist for environmental justice            1         35     18.60
# 5     Global health expert; data visionary            1         48     19.83
# ...                                    ...          ...        ...       ...
# 2550                            Journalist            1          4      7.93
# 2551                        Astrobiologist            1          3      4.83
# 2552                     Robotics engineer            1          1     10.85
# 2553                   Public intellectual            1          1     18.33
# 2554                         Game designer            1          1      8.65
#
#              event                                               tags  \
# 0          TED2006  ['children', 'creativity', 'culture', 'dance',...
# 2          TED2006  ['alternative energy', 'cars', 'climate change...
# 3          TED2006  ['computers', 'entertainment', 'interface desi...
# 4          TED2006  ['MacArthur grant', 'activism', 'business', 'c...
# 5          TED2006  ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...            ...                                                ...
# 2550       TED2017  ['TED Residency', 'United States', 'community'...
# 2551       TED2017  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2552       TED2017  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2553  TEDxMileHigh  ['Internet', 'TEDx', 'United States', 'communi...
# 2554       TED2017  ['cities', 'design', 'future', 'infrastructure...
#
#                                                 ratings  \
# 0     {'funny': {'id': 7, 'count': 19645}, 'beautifu...
# 2     {'funny': {'id': 7, 'count': 544}, 'courageous...
# 3     {'funny': {'id': 7, 'count': 964}, 'courageous...
# 4     {'courageous': {'id': 3, 'count': 760}, 'beaut...
# 5     {'ingenious': {'id': 9, 'count': 3202}, 'funny...
# ...                                                 ...
# 2550  {'courageous': {'id': 3, 'count': 24}, 'inform...
# 2551  {'fascinating': {'id': 22, 'count': 32}, 'info...
# 2552  {'beautiful': {'id': 1, 'count': 14}, 'informa...
# 2553  {'longwinded': {'id': 11, 'count': 3}, 'unconv...
# 2554  {'unconvincing': {'id': 21, 'count': 21}, 'inf...
#
#                                           related_talks   film_date  \
# 0     [Bring on the learning revolution!, How to esc...  1140825600
# 2     [New thinking on the climate crisis, The busin...  1140825600
# 3     [10 top time-saving tech tips, The first secre...  1140739200
# 4     [3 stories of local eco-entrepreneurship, A ne...  1140912000
# 5     [Own your body's data, A visual history of hum...  1140566400
# ...                                                 ...         ...
# 2550  [Immigrant voices make democracy stronger, Why...  1496707200
# 2551  [Adventures of an asteroid hunter, Why Earth m...  1492992000
# 2552  [The future of flying robots, Meet Spot, the r...  1492992000
# 2553  [How barbershops can keep men healthy, We need...  1499472000
# 2554  [4 ways to make a city more walkable, 7 princi...  1492992000
#
#               film_date_hr  published_date     published_date_hr  \
# 0     02/24/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 2     02/24/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 3     02/23/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 4     02/25/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 5     02/21/2006, 19:00:00      1151440680  06/27/2006, 16:38:00
# ...                    ...             ...                   ...
# 2550  06/05/2017, 20:00:00      1505851216  09/19/2017, 16:00:16
# 2551  04/23/2017, 20:00:00      1505919737  09/20/2017, 11:02:17
# 2552  04/23/2017, 20:00:00      1506006095  09/21/2017, 11:01:35
# 2553  07/07/2017, 20:00:00      1506024042  09/21/2017, 16:00:42
# 2554  04/23/2017, 20:00:00      1506092422  09/22/2017, 11:00:22
#
#                                                     url  comments     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...      4553  47227110
# 2     https://www.ted.com/talks/al_gore_on_averting_...       265   3200520
# 3     https://www.ted.com/talks/david_pogue_says_sim...       124   1636292
# 4     https://www.ted.com/talks/majora_carter_s_tale...       200   1697550
# 5     https://www.ted.com/talks/hans_rosling_shows_t...       593  12005869
# ...                                                 ...       ...       ...
# 2550  https://www.ted.com/talks/duarte_geraldino_wha...        17    450430
# 2551  https://www.ted.com/talks/armando_azua_bustos_...         6    417470
# 2552  https://www.ted.com/talks/radhika_nagpal_what_...        10    375647
# 2553  https://www.ted.com/talks/theo_e_j_wilson_a_bl...        32    419309
# 2554  https://www.ted.com/talks/karoliina_korppoo_ho...         8    391721
#
# [2550 rows x 18 columns]

# %%
df2 = pd.read_csv('../datasets/ted_talks_transcripts.csv')

# %%
df2.iloc[:,:2]
# Out:
#                                              transcript  \
# 0     Good morning. How are you?(Laughter)It's been ...
# 1     Thank you so much, Chris. And it's truly a gre...
# 2     (Music: "The Sound of Silence," Simon & Garfun...
# 3     If you're here today — and I'm very happy that...
# 4     About 10 years ago, I took on the task to teac...
# ...                                                 ...
# 2470  So, Ma was trying to explain something to me a...
# 2471  This is a picture of a sunset on Mars taken by...
# 2472  In my early days as a graduate student, I went...
# 2473  I took a cell phone and accidentally made myse...
# 2474  We humans are becoming an urban species, so ci...
#
#                                                     url
# 0     https://www.ted.com/talks/ken_robinson_says_sc...
# 1     https://www.ted.com/talks/al_gore_on_averting_...
# 2     https://www.ted.com/talks/david_pogue_says_sim...
# 3     https://www.ted.com/talks/majora_carter_s_tale...
# 4     https://www.ted.com/talks/hans_rosling_shows_t...
# ...                                                 ...
# 2470  https://www.ted.com/talks/duarte_geraldino_wha...
# 2471  https://www.ted.com/talks/armando_azua_bustos_...
# 2472  https://www.ted.com/talks/radhika_nagpal_what_...
# 2473  https://www.ted.com/talks/theo_e_j_wilson_a_bl...
# 2474  https://www.ted.com/talks/karoliina_korppoo_ho...
#
# [2475 rows x 2 columns]

# %%
help(df.merge)

# %%
df = df.merge(df2.iloc[:,:2], on="url")

# %%
df.to_csv('../datasets/cleaned_ted_talks.csv', index=False)

# %%
cleaned_df = pd.read_csv('../datasets/cleaned_ted_talks.csv')

# %%
cleaned_df
# Out:
#                                                   title  \
# 0                           Do schools kill creativity?
# 1                           Averting the climate crisis
# 2                                      Simplicity sells
# 3                                   Greening the ghetto
# 4                       The best stats you've ever seen
# ...                                                 ...
# 2458  What we're missing in the debate about immigra...
# 2459                    The most Martian place on Earth
# 2460  What intelligent machines can learn from a sch...
# 2461       A black man goes undercover in the alt-right
# 2462  How a video game might help us build better ci...
#
#                                             description         main_speaker  \
# 0     Sir Ken Robinson makes an entertaining and pro...         Ken Robinson
# 1     With the same humor and humanity he exuded in ...              Al Gore
# 2     New York Times columnist David Pogue takes aim...          David Pogue
# 3     In an emotionally charged talk, MacArthur-winn...        Majora Carter
# 4     You've never seen data presented like this. Wi...         Hans Rosling
# ...                                                 ...                  ...
# 2458  Between 2008 and 2016, the United States depor...     Duarte Geraldino
# 2459  How can you study Mars without a spaceship? He...  Armando Azua-Bustos
# 2460  Science fiction visions of the future show us ...       Radhika Nagpal
# 2461  In an unmissable talk about race and politics ...     Theo E.J. Wilson
# 2462  With more than half of the world population li...    Karoliina Korppoo
#
#                         speaker_occupation  num_speaker  languages  duration  \
# 0                          Author/educator            1         60     19.40
# 1                         Climate advocate            1         43     16.28
# 2                     Technology columnist            1         26     21.43
# 3       Activist for environmental justice            1         35     18.60
# 4     Global health expert; data visionary            1         48     19.83
# ...                                    ...          ...        ...       ...
# 2458                            Journalist            1          4      7.93
# 2459                        Astrobiologist            1          3      4.83
# 2460                     Robotics engineer            1          1     10.85
# 2461                   Public intellectual            1          1     18.33
# 2462                         Game designer            1          1      8.65
#
#              event                                               tags  \
# 0          TED2006  ['children', 'creativity', 'culture', 'dance',...
# 1          TED2006  ['alternative energy', 'cars', 'climate change...
# 2          TED2006  ['computers', 'entertainment', 'interface desi...
# 3          TED2006  ['MacArthur grant', 'activism', 'business', 'c...
# 4          TED2006  ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...            ...                                                ...
# 2458       TED2017  ['TED Residency', 'United States', 'community'...
# 2459       TED2017  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2460       TED2017  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2461  TEDxMileHigh  ['Internet', 'TEDx', 'United States', 'communi...
# 2462       TED2017  ['cities', 'design', 'future', 'infrastructure...
#
#                                                 ratings  \
# 0     {'funny': {'id': 7, 'count': 19645}, 'beautifu...
# 1     {'funny': {'id': 7, 'count': 544}, 'courageous...
# 2     {'funny': {'id': 7, 'count': 964}, 'courageous...
# 3     {'courageous': {'id': 3, 'count': 760}, 'beaut...
# 4     {'ingenious': {'id': 9, 'count': 3202}, 'funny...
# ...                                                 ...
# 2458  {'courageous': {'id': 3, 'count': 24}, 'inform...
# 2459  {'fascinating': {'id': 22, 'count': 32}, 'info...
# 2460  {'beautiful': {'id': 1, 'count': 14}, 'informa...
# 2461  {'longwinded': {'id': 11, 'count': 3}, 'unconv...
# 2462  {'unconvincing': {'id': 21, 'count': 21}, 'inf...
#
#                                           related_talks   film_date  \
# 0     ['Bring on the learning revolution!', "How to ...  1140825600
# 1     ['New thinking on the climate crisis', 'The bu...  1140825600
# 2     ['10 top time-saving tech tips', 'The first se...  1140739200
# 3     ['3 stories of local eco-entrepreneurship', 'A...  1140912000
# 4     ["Own your body's data", 'A visual history of ...  1140566400
# ...                                                 ...         ...
# 2458  ['Immigrant voices make democracy stronger', '...  1496707200
# 2459  ['Adventures of an asteroid hunter', 'Why Eart...  1492992000
# 2460  ['The future of flying robots', 'Meet Spot, th...  1492992000
# 2461  ['How barbershops can keep men healthy', 'We n...  1499472000
# 2462  ['4 ways to make a city more walkable', '7 pri...  1492992000
#
#               film_date_hr  published_date     published_date_hr  \
# 0     02/24/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 1     02/24/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 2     02/23/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 3     02/25/2006, 19:00:00      1151367060  06/26/2006, 20:11:00
# 4     02/21/2006, 19:00:00      1151440680  06/27/2006, 16:38:00
# ...                    ...             ...                   ...
# 2458  06/05/2017, 20:00:00      1505851216  09/19/2017, 16:00:16
# 2459  04/23/2017, 20:00:00      1505919737  09/20/2017, 11:02:17
# 2460  04/23/2017, 20:00:00      1506006095  09/21/2017, 11:01:35
# 2461  07/07/2017, 20:00:00      1506024042  09/21/2017, 16:00:42
# 2462  04/23/2017, 20:00:00      1506092422  09/22/2017, 11:00:22
#
#                                                     url  comments     views  \
# 0     https://www.ted.com/talks/ken_robinson_says_sc...      4553  47227110
# 1     https://www.ted.com/talks/al_gore_on_averting_...       265   3200520
# 2     https://www.ted.com/talks/david_pogue_says_sim...       124   1636292
# 3     https://www.ted.com/talks/majora_carter_s_tale...       200   1697550
# 4     https://www.ted.com/talks/hans_rosling_shows_t...       593  12005869
# ...                                                 ...       ...       ...
# 2458  https://www.ted.com/talks/duarte_geraldino_wha...        17    450430
# 2459  https://www.ted.com/talks/armando_azua_bustos_...         6    417470
# 2460  https://www.ted.com/talks/radhika_nagpal_what_...        10    375647
# 2461  https://www.ted.com/talks/theo_e_j_wilson_a_bl...        32    419309
# 2462  https://www.ted.com/talks/karoliina_korppoo_ho...         8    391721
#
#                                              transcript
# 0     Good morning. How are you?(Laughter)It's been ...
# 1     Thank you so much, Chris. And it's truly a gre...
# 2     (Music: "The Sound of Silence," Simon & Garfun...
# 3     If you're here today — and I'm very happy that...
# 4     About 10 years ago, I took on the task to teac...
# ...                                                 ...
# 2458  So, Ma was trying to explain something to me a...
# 2459  This is a picture of a sunset on Mars taken by...
# 2460  In my early days as a graduate student, I went...
# 2461  I took a cell phone and accidentally made myse...
# 2462  We humans are becoming an urban species, so ci...
#
# [2463 rows x 19 columns]

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Lab</h1>
# </div>

# %% [markdown]
# For today's lab, we'll be using the Marvel comic book characters data set available from [538](https://github.com/fivethirtyeight/data/tree/master/comic-characters)
#
# The data comes from [Marvel Wikia](http://marvel.wikia.com/Main_Page) and [DC Wikia](http://dc.wikia.com/wiki/Main_Page). Characters were scraped on August 24. Appearance counts were scraped on September 2. The month and year of the first issue each character appeared in was pulled on October 6.
#
# The data is split into two files, for DC and Marvel, respectively: `dc-wikia-data.csv` and `marvel-wikia-data.csv`. Each file has the following variables:
#
# Variable | Definition
# ---|---------
# `page_id` | The unique identifier for that characters page within the wikia
# `name` | The name of the character
# `urlslug` | The unique url within the wikia that takes you to the character
# `ID` | The identity status of the character (Secret Identity, Public identity, [on marvel only: No Dual Identity])
# `ALIGN` | If the character is Good, Bad or Neutral
# `EYE` | Eye color of the character
# `HAIR` | Hair color of the character
# `SEX` | Sex of the character (e.g. Male, Female, etc.)
# `GSM` | If the character is a gender or sexual minority (e.g. Homosexual characters, bisexual characters)
# `ALIVE` | If the character is alive or deceased
# `APPEARANCES` | The number of appareances of the character in comic books (as of Sep. 2, 2014. Number will become increasingly out of date as time goes on.)
# `FIRST APPEARANCE` | The month and year of the character's first appearance in a comic book, if available
# `YEAR` | The year of the character's first appearance in a comic book, if available

# %% [markdown]
# Importing the libraries we'll be using

# %%
import numpy as np 
import pandas as pd 
import datetime

# %% [markdown]
# Let's open the `marvel-wikia-data.csv` file and generate a dataframe. Then we'll check the top of the `df` to see what we have.

# %%
df = pd.read_csv("../datasets/marvel-wikia-data.csv")
df.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0  Living Characters       4043.0           Aug-62  1962.0
# 1  Living Characters       3360.0           Mar-41  1941.0
# 2  Living Characters       3061.0           Oct-74  1974.0
# 3  Living Characters       2961.0           Mar-63  1963.0
# 4  Living Characters       2258.0           Nov-50  1950.0

# %% [markdown]
# As you can see we have a couple of issues:
# * The column `names` has, in some cases, both the hero name and their secret identity. In other cases, it has the universe the hero is from (usually Earth-616). We'd like for `name` to be the superhero. If a secret identity name is available, we'd like for that to be in it's own column. We'd also like a column `origin` for the superhero's place of origin (usually Earth-616).
# * The `urlslug` column is incorrect. We'd like for that to be a complete link. For example, spiderman's wikia link is https://marvel.fandom.com/wiki/Peter_Parker_(Earth-616) but if you use the `Spider-Man_(Peter_Parker)` from the `urlslug` (https://marvel.fandom.com/wiki/Spider-Man_(Peter_Parker), the page redirects to the correct page. You can choose to fix it various different ways but it should be a working link. Use "https://marvel.fandom.com/wiki/" as the beginning of your url.
# * For the column `align`, we'd like for the "Characters" part to be removed. We'd like for that column to be categorical (Good, Neutral, Evil or blank).
# * Same for the columns `EYE`, `HAIR`, `SEX` and `ID`. We want to drop the extraneous data and have simple categories (e.g. for `ID` we want categories ["Known","Public", "Secret", "None"] and for `SEX` we just want ["Male", "Female","Genderfluid","Agender"]. There's a way shown below that shows the various possible categories.
# * Some data is in the wrong format. For example, `Year` and `APPEARANCES` are floats but they really should be ints (as you cannot have a non-int number of appearances).
# * Some data doesn't match up (like the `FIRST APPEARANCE` and `Year` columns might have not be the same year)
# * Some columns are unnecessary. Some are missing data. Some rows are duplicates. Fix those as necessary.
# * Some column names are written as uppercase, some are lowercase and some are mixed case. Normalize them so all the column names are in the same format.
#
# Fix as many of these issues as you're able to. At the minimum, complete 4 of the above bulletpoints.

# %%
def see_possible_categories(col):
    return df.groupby(col).sum()
    
see_possible_categories('name')
